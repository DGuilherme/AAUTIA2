# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/Challenge3/blob/main/CH3_PatentRS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge 3 Patent Reconmmender System

# %%
# Import section
# %matplotlib inline

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# solve issue of gensim version
# !pip install --upgrade gensim
# Out:
# Requirement already up-to-date: gensim in /usr/local/lib/python3.7/dist-packages (4.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.0.0)

# %% [markdown]
# # Import Dataset
#
# *Dataset composition*
#
# | Feature        | Description           |
# | -------------- | --------------------- |
# | ID             | The patent ID         |
# | Title          | Patent Title          |
# | Abstract       | Patent Abstract       |
# | Classification | [Patent Classification](https://www.uspto.gov/web/patents/classification/selectnumwithtitle.htm) |
#
# ## How to export from database
#
#
# ```
# db.10000.find(
#   {'classes.FSC': {$exists: true},title: {$exists: true},'abstract': {$exists: true}},
#   {'abstract': 1,title: 1,'classes.FSC': 1}
# )
# ```
#
#
# ```
# [{$sample: {
#   size: 10000
# }}, {$project: { _id: {$toString: "$_id"}, abstract : 1, title : 1, "classes.FSC" :1}}, {$match: {"classes" :{"$exists":true},title:{"$exists":true},abstract:{"$exists":true}}}]
# ```

# %%
url = 'https://raw.githubusercontent.com/DGuilherme/Challenge3/main/Dataset/10000_classified_patents.json'

# %% [markdown]
# # Preprocessing

# %%
from sklearn.model_selection import train_test_split

raw_train_data = pd.read_json(url)
raw_train_data = raw_train_data.rename(columns={'_id': 'ID', 'abstract': 'Resumo','title': 'Titulo'})
raw_train_data = raw_train_data.dropna()
raw_train_data = raw_train_data.drop_duplicates(subset ="Resumo",keep = False)
raw_train_data = raw_train_data.drop_duplicates(subset ="Titulo",keep = False)
train_classes_data = raw_train_data[['ID','classes']]
train_data_unsplit = raw_train_data[['ID','Titulo','Resumo']]

# Split dataset
train_data, test_data = train_test_split(train_data_unsplit, test_size=0.2)

# %%
train_data_unsplit.describe()
# Out:
#                               ID  ...                                             Resumo
# count                       7311  ...                                               7311
# unique                      7311  ...                                               7311
# top     57066c4eeb1ec98afebe694d  ...  A powder lacquer binder composition which comp...
# freq                           1  ...                                                  1
#
# [4 rows x 3 columns]

# %%
raw_train_data.describe()
# Out:
#                                                    Resumo  ...                        ID
# count                                                7311  ...                      7311
# unique                                               7311  ...                      7311
# top     A powder lacquer binder composition which comp...  ...  57066c4eeb1ec98afebe694d
# freq                                                    1  ...                         1
#
# [4 rows x 4 columns]

# %%
train_classes_data.describe()
print(train_classes_data)
# Out:
#                             ID                                    classes
# 0     57065f86eb1ec950df04567a                    {'FSC': ['359', '372']}
# 1     5702662eeb1ec9c195055491                              {'FSC': '84'}
# 2     57026579eb1ec9b0a9bd00fe  {'FSC': ['72', '29', '51', '408', '409']}
# 3     570260bbeb1ec9244e6bdfe1                    {'FSC': ['210', '429']}
# 4     57026060eb1ec91ddf3047ef       {'FSC': ['144', '254', '173', '81']}
# ...                        ...                                        ...
# 7360  570261d1eb1ec93bc90e06ea                             {'FSC': '424'}
# 7361  57066c52eb1ec98afebf7a43                             {'FSC': '424'}
# 7362  57064db8eb1ec901ec1acac0                     {'FSC': ['53', '141']}
# 7363  570261d1eb1ec93bc90de880                    {'FSC': ['248', '285']}
# 7364  57066c52eb1ec98afebf58ad                              {'FSC': '62'}
#
# [7311 rows x 2 columns]

# %% [markdown]
# # Create the Vocabulary

# %%
modelIndexToDataframeIndex = []

import gensim

def tagData(dataframe):
  number = 0
  for index,row in dataframe.iterrows():
    number = number + 1
    modelIndexToDataframeIndex.append(row['ID'])
    resumotokens = gensim.utils.simple_preprocess(row['Resumo'])

    yield gensim.models.doc2vec.TaggedDocument(resumotokens, [number])

vocabulary = list(tagData(train_data))
vocabulary_test = list(tagData(test_data))
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # User Question

# %% [markdown]
# # Create gensim Doc2Vec model

# %%
# instanciate
model = gensim.models.doc2vec.Doc2Vec(vector_size=100, min_count=2, epochs=100) # Create inital empty model

# build
model.build_vocab(vocabulary) # Add data to the model
# Out:
# 2021-04-24 15:46:07,212 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec(dm/m,d100,n5,w5,mc2,s0.001,t3)', 'datetime': '2021-04-24T15:46:07.212375', 'gensim': '4.0.1', 'python': '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'created'}
# 2021-04-24 15:46:07,214 : INFO : collecting all words and their counts
# 2021-04-24 15:46:07,216 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2021-04-24 15:46:07,374 : INFO : collected 19135 word types and 5849 unique tags from a corpus of 5848 examples and 654411 words
# 2021-04-24 15:46:07,375 : INFO : Creating a fresh vocabulary
# 2021-04-24 15:46:07,440 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 retains 12676 unique words (66.24510060099294%% of original 19135, drops 6459)', 'datetime': '2021-04-24T15:46:07.440196', 'gensim': '4.0.1', 'python': '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2021-04-24 15:46:07,442 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 647952 word corpus (99.01300558823125%% of original 654411, drops 6459)', 'datetime': '2021-04-24T15:46:07.442762', 'gensim': '4.0.1', 'python': '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2021-04-24 15:46:07,531 : INFO : deleting the raw counts dictionary of 19135 items
# 2021-04-24 15:46:07,533 : INFO : sample=0.001 downsamples 31 most-common words
# 2021-04-24 15:46:07,536 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 485390.88449668745 word corpus (74.9%% of prior 647952)', 'datetime': '2021-04-24T15:46:07.536158', 'gensim': '4.0.1', 'python': '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2021-04-24 15:46:07,696 : INFO : estimated required memory for 12676 words and 100 dimensions: 19988200 bytes
# 2021-04-24 15:46:07,698 : INFO : resetting layer weights

# %% [markdown]
# # Model Train

# %%
model.train(vocabulary, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2021-04-24 15:46:07,722 : INFO : Doc2Vec lifecycle event {'msg': 'training model with 3 workers on 12676 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:27,862 : INFO : EPOCH - 93 : training on 654411 raw words (491225 effective words) took 1.5s, 330851 effective words/s
# 2021-04-24 15:48:28,883 : INFO : EPOCH 94 - PROGRESS: at 69.68% examples, 338522 words/s, in_qsize 5, out_qsize 0
# 2021-04-24 15:48:29,308 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:29,319 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:29,326 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:29,328 : INFO : EPOCH - 94 : training on 654411 raw words (491152 effective words) took 1.5s, 337026 effective words/s
# 2021-04-24 15:48:30,374 : INFO : EPOCH 95 - PROGRESS: at 68.09% examples, 324652 words/s, in_qsize 6, out_qsize 0
# 2021-04-24 15:48:30,785 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:30,796 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:30,805 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:30,807 : INFO : EPOCH - 95 : training on 654411 raw words (491053 effective words) took 1.5s, 335075 effective words/s
# 2021-04-24 15:48:31,828 : INFO : EPOCH 96 - PROGRESS: at 66.52% examples, 323155 words/s, in_qsize 5, out_qsize 0
# 2021-04-24 15:48:32,309 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:32,331 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:32,342 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:32,343 : INFO : EPOCH - 96 : training on 654411 raw words (491097 effective words) took 1.5s, 321201 effective words/s
# 2021-04-24 15:48:33,357 : INFO : EPOCH 97 - PROGRESS: at 66.59% examples, 327410 words/s, in_qsize 5, out_qsize 0
# 2021-04-24 15:48:33,804 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:33,821 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:33,840 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:33,842 : INFO : EPOCH - 97 : training on 654411 raw words (490960 effective words) took 1.5s, 330517 effective words/s
# 2021-04-24 15:48:34,858 : INFO : EPOCH 98 - PROGRESS: at 69.55% examples, 340227 words/s, in_qsize 5, out_qsize 0
# 2021-04-24 15:48:35,262 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:35,289 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:35,294 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:35,296 : INFO : EPOCH - 98 : training on 654411 raw words (491315 effective words) took 1.4s, 339981 effective words/s
# 2021-04-24 15:48:36,308 : INFO : EPOCH 99 - PROGRESS: at 68.09% examples, 334346 words/s, in_qsize 6, out_qsize 0
# 2021-04-24 15:48:36,728 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:36,735 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:36,751 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:36,753 : INFO : EPOCH - 99 : training on 654411 raw words (491155 effective words) took 1.4s, 339241 effective words/s
# 2021-04-24 15:48:37,797 : INFO : EPOCH 100 - PROGRESS: at 69.55% examples, 331551 words/s, in_qsize 5, out_qsize 0
# 2021-04-24 15:48:38,200 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-04-24 15:48:38,216 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-04-24 15:48:38,228 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-24 15:48:38,231 : INFO : EPOCH - 100 : training on 654411 raw words (491635 effective words) took 1.5s, 334933 effective words/s
# 2021-04-24 15:48:38,235 : INFO : Doc2Vec lifecycle event {'msg': 'training on 65441100 raw words (49120440 effective words) took 150.5s, 326359 effective words/s', 'datetime': '2021-04-24T15:48:38.235490', 'gensim': '4.0.1', 'python': '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'train'}

# %% [markdown]
# # Model Test

# %%
# Pick a random document from the test corpus and infer a vector from the model
sample = train_data.sample()
print("ID: "+ sample.iloc[0]['ID'])
print("Resumo: "+ sample.iloc[0]['Titulo'])
print("Titulo: "+ sample.iloc[0]['Resumo'])
value = str(sample.iloc[0]['ID'])
fscList = train_classes_data.iloc[sample.index]['classes'].iloc[0]['FSC']
print("FSC: "+ str(fscList))
# Out:
# ID: 5706821beb1ec9ebf6b44742
# Resumo: Aluminum offset coil, and method for its production
# Titulo: An aluminum offset coil, having a surface zone of a predominantly recrystallized globular, fine grain structure, and a core zone of a greatly work-hardened structure, for use in offset printing plates, and a process for its preparation.
# FSC: ['74', '364', '192', '123']

# %%
inferred_vector = model.infer_vector(gensim.utils.simple_preprocess(sample.iloc[0]['Resumo']))
sims = model.dv.most_similar([inferred_vector], topn=len(model.dv))
best_match_row = train_data[train_data['ID'] == modelIndexToDataframeIndex[sims[1][0]-1]]
print("Similarity: "+ str(sims[1][1]))
print("ID: "+ best_match_row.iloc[0]['ID'])
print("Resumo: "+ best_match_row.iloc[0]['Titulo'])
print("Titulo: "+ best_match_row.iloc[0]['Resumo'])
value = str(best_match_row.iloc[0]['ID'])
fscList = train_classes_data.iloc[best_match_row.index]['classes'].iloc[0]['FSC']
print("FSC: "+ str(fscList))
# Out:
# Similarity: 0.4567660987377167
# ID: 570641eaeb1ec9cd7cacc6f0
# Resumo: Hydrotreating catalysts prepared from hydrogels
# Titulo: This invention relates to a process for preparing highly active hydrotreating catalysts prepared by incorporating cobalt and an element selected from the group consisting of molybdenum, tungsten and mixtures thereof, into a phosphated alumina hydrogel support. The final calcined catalysts have surface areas greater than about 300 m.sup.2 /g, flat plate crush strengths greater than about 18 lbs and more than about 80% of their pore volume in pores having diameters less than about 70 .ANG..
# FSC: ['347', '399']

# %%
def get_model_best_match(abstract):
  inferred_vector = model.infer_vector(gensim.utils.simple_preprocess(abstract))
  return model.dv.most_similar([inferred_vector], topn=len(model.dv))

def get_FSC_classes_row(ID):
  best_match_classes = train_classes_data[train_classes_data['ID'] == ID]
  return best_match_classes['classes'].iloc[0]
  
def validate_parse_fsc(row_fsc):
  fscList = []
  if('FSC' in row_fsc):
    fscList = row_fsc['FSC']
    
    if(not isinstance(fscList,list)):
      fscList = [fscList]
    
  return fscList

def evaluate_classes():
  for index,row in test_data.iterrows():
    test_Data_sample = get_model_best_match(row['Resumo'])
    match_ID = str(modelIndexToDataframeIndex[test_Data_sample[0][0]-1])

    best_match_data = train_data[train_data['ID'] == match_ID]
    
    best_match_fsc_row = get_FSC_classes_row(match_ID)
    test_fsc_row = get_FSC_classes_row(row['ID'])
  
    fsc_list_best_match = validate_parse_fsc(best_match_fsc_row)
    fsc_test_data_row = validate_parse_fsc(test_fsc_row)

    print("Best Match FSC: " + str(fsc_list_best_match))
    print("Row FSC: " + str(fsc_test_data_row) + "\n")


evaluate_classes()
# Out:
# Best Match FSC: ['399', '271']
# Row FSC: ['250', '318', '356', '156']
#
# Best Match FSC: ['134', '49', '160']
# Row FSC: ['119', '229']
#
# Best Match FSC: ['280', '297']
# Row FSC: ['280', '403']
#
# Best Match FSC: ['235', '271']
# Row FSC: ['428']
#
# Best Match FSC: ['424']
# Row FSC: ['55', '134', '210', '252', '427']
#
# Best Match FSC: ['8', '428', '503']
# Row FSC: ['96', '428']
#
# Best Match FSC: ['568']
# Row FSC: ['528']
#
# Best Match FSC: ['260']
# Row FSC: ['576', '514']
#
# Best Match FSC: ['362', '40', '52', '431', '206']
# Row FSC: ['220', '206']
#
# Best Match FSC: ['556']
# Row FSC: ['72', '29', '451']
#
# Best Match FSC: ['423']
# Row FSC: ['442']
#
# Best Match FSC: ['252', '8', '510']
# Row FSC: ['260']
#
# Best Match FSC: ['530']
# Row FSC: ['530']
#
# Best Match FSC: ['544', '504']
# Row FSC: ['296', '307', '318']
#
# Best Match FSC: ['246', '73']
# Row FSC: ['441', '114']
#
# Best Match FSC: ['544', '8']
# Row FSC: ['534']
#
# Best Match FSC: ['180', '317', '123']
# Row FSC: ['244', '62', '165', '123', '60']
#
# Best Match FSC: ['375', '455', '370']
# Row FSC: ['701']
#
# Best Match FSC: ['424']
# Row FSC: ['424', '514']
#
# Best Match FSC: ['364', '371']
# Row FSC: ['364', '318', '425', '264', '29']
#
# Best Match FSC: ['525']
# Row FSC: ['423', '106', '264', '501']
#
# Best Match FSC: ['528', '525', '428']
# Row FSC: ['260', '162', '57', '428']
#
# Best Match FSC: ['184', '220', '215', '206', '141']
# Row FSC: ['72', '29', '100']
#
# Best Match FSC: ['73', '141', '206', '340']
# Row FSC: ['60', '123']
#
# Best Match FSC: ['369']
# Row FSC: ['705', '235']
#
# Best Match FSC: ['366', '241']
# Row FSC: ['57']
#
# Best Match FSC: ['360', '242']
# Row FSC: ['280', '182', '105']
#
# Best Match FSC: ['514']
# Row FSC: ['424', '514']
#
# Best Match FSC: ['428', '52']
# Row FSC: ['604']
#
# Best Match FSC: ['540', '544', '546', '549', '514']
# Row FSC: ['548', '514']
#
# Best Match FSC: ['110']
# Row FSC: ['417', '165', '62', '123']
#
# Best Match FSC: ['368']
# Row FSC: ['219', '364']
#
# Best Match FSC: ['166', '252']
# Row FSC: ['210']
#
# Best Match FSC: ['364', '382']
# Row FSC: ['369', '360']
#
# Best Match FSC: ['294', '16', '24', '211', '224', '248', '273']
# Row FSC: ['128', '312', 'D 6', '4']
#
# Best Match FSC: ['252']
# Row FSC: ['406']
#
# Best Match FSC: ['42', '89']
# Row FSC: ['137', '92']
#
# Best Match FSC: ['427']
# Row FSC: ['52']
#
# Best Match FSC: ['Plt']
# Row FSC: ['Plt']
#
# Best Match FSC: ['364']
# Row FSC: ['257', '438']
#
# Best Match FSC: ['349', '428']
# Row FSC: ['455', '334']
#
# Best Match FSC: ['437', '438']
# Row FSC: ['362']
#
# Best Match FSC: ['250', '257']
# Row FSC: ['422', '73', '250', '324']
#
# Best Match FSC: ['206', '220']
# Row FSC: ['206', '116', '246', '40']
#
# Best Match FSC: ['126', '122', '237', '202']
# Row FSC: ['210', '204']
#
# Best Match FSC: ['548']
# Row FSC: ['424']
#
# Best Match FSC: ['379']
# Row FSC: ['395']
#
# Best Match FSC: ['74', '192']
# Row FSC: ['192']
#
# Best Match FSC: ['56', '248']
# Row FSC: ['359']
#
# Best Match FSC: ['296', '280', '248', '297']
# Row FSC: ['180', '901']
#
# Best Match FSC: ['525', '428']
# Row FSC: ['514', '530']
#
# Best Match FSC: ['430', '369', '359', '428']
# Row FSC: ['430', '358']
#
# Best Match FSC: ['430']
# Row FSC: ['148', '420']
#
# Best Match FSC: ['709']
# Row FSC: ['2', '224', '40', '46']
#
# Best Match FSC: ['365', '371']
# Row FSC: ['365']
#
# Best Match FSC: ['192']
# Row FSC: ['73']
#
# Best Match FSC: ['315', '313', '376']
# Row FSC: ['355', '118', '430']
#
# Best Match FSC: ['315']
# Row FSC: ['315', '327', '363']
#
# Best Match FSC: ['417']
# Row FSC: ['428']
#
# Best Match FSC: ['435', '530']
# Row FSC: ['435', '536']
#
# Best Match FSC: ['544', '514', '540']
# Row FSC: ['530']
#
# Best Match FSC: ['425', '366', '264']
# Row FSC: ['152', '417', '418']
#
# Best Match FSC: ['204']
# Row FSC: ['930', '530', '426', '514', '424']
#
# Best Match FSC: ['37', '172']
# Row FSC: ['600', '482', '73']
#
# Best Match FSC: ['329', '307', '363']
# Row FSC: ['73', '376', '310']
#
# Best Match FSC: ['424']
# Row FSC: ['521', '524']
#
# Best Match FSC: ['709']
# Row FSC: ['381', '395']
#
# Best Match FSC: ['370']
# Row FSC: ['359']
#
# Best Match FSC: ['Plt']
# Row FSC: ['PLT']
#
# Best Match FSC: ['435', '530']
# Row FSC: ['548', '546']
#
# Best Match FSC: ['235']
# Row FSC: ['370', '375']
#
# Best Match FSC: ['424', '514']
# Row FSC: ['514', '435', '536', '935']
#
# Best Match FSC: ['29', '174', '437', '264', '257']
# Row FSC: ['257', '437', '365', '438']
#
# Best Match FSC: ['313', '359']
# Row FSC: ['350', '365', '252']
#
# Best Match FSC: ['431', '239']
# Row FSC: ['128', '514']
#
# Best Match FSC: ['435']
# Row FSC: ['562']
#
# Best Match FSC: ['439']
# Row FSC: ['180', '70']
#
# Best Match FSC: ['364', '324']
# Row FSC: ['367', '73', '33', '181', '250', '175']
#
# Best Match FSC: ['216', '438', '134']
# Row FSC: ['242']
#
# Best Match FSC: ['378']
# Row FSC: ['250']
#
# Best Match FSC: ['439', '385']
# Row FSC: ['439']
#
# Best Match FSC: ['134', '49', '160']
# Row FSC: ['99', '126']
#
# Best Match FSC: ['428', '347']
# Row FSC: ['428', '525']
#
# Best Match FSC: ['473', '525']
# Row FSC: ['252', '423', '208']
#
# Best Match FSC: ['272', '446', '63', '434', '273', '128', '84']
# Row FSC: ['16', '160']
#
# Best Match FSC: ['430', '525', '526']
# Row FSC: ['96', '204', '427', '526', '264']
#
# Best Match FSC: ['250', '356']
# Row FSC: ['248', '312', '211']
#
# Best Match FSC: ['435', '800', '514', '530', '935', '536']
# Row FSC: ['623']
#
# Best Match FSC: ['370']
# Row FSC: ['455', '704', '370']
#
# Best Match FSC: ['426', '428', '206']
# Row FSC: ['524', '523']
#
# Best Match FSC: ['436', '435', '424', '935']
# Row FSC: ['363', '318']
#
# Best Match FSC: ['428', '264']
# Row FSC: ['65', '427']
#
# Best Match FSC: ['371', '395', '370']
# Row FSC: ['370', '395']
#
# Best Match FSC: ['260', '208']
# Row FSC: ['241']
#
# Best Match FSC: ['81']
# Row FSC: ['118', '355']
#
# Best Match FSC: ['156', '264', '427']
# Row FSC: ['524', '523', '525', '428']
#
# Best Match FSC: ['164']
# Row FSC: ['427', '282', '428']
#
# Best Match FSC: ['313', '359', '362']
# Row FSC: ['294', '30', '15', 'D 7']
#
# Best Match FSC: ['424']
# Row FSC: ['435']
#
# Best Match FSC: ['355', '371', '364']
# Row FSC: ['361']
#
# Best Match FSC: ['318']
# Row FSC: ['73', '324']
#
# Best Match FSC: ['340', '320', '455']
# Row FSC: ['250']
#
# Best Match FSC: ['355', '118', '430']
# Row FSC: ['360']
#
# Best Match FSC: ['355', '361']
# Row FSC: ['96', '118', '356', '355']
#
# Best Match FSC: ['123']
# Row FSC: ['141', '220']
#
# Best Match FSC: ['206']
# Row FSC: ['15', '55']
#
# Best Match FSC: ['455', '375']
# Row FSC: ['395', '355', '399']
#
# Best Match FSC: ['84']
# Row FSC: ['425']
#
# Best Match FSC: ['424', '530', '435']
# Row FSC: ['435', '436']
#
# Best Match FSC: ['482', '606', '128', 'D21', 'D24', 'D29']
# Row FSC: ['37', '59', '24']
#
# Best Match FSC: ['438']
# Row FSC: ['438']
#
# Best Match FSC: ['15']
# Row FSC: ['239', '46']
#
# Best Match FSC: ['521', '525', '528']
# Row FSC: ['260', '526']
#
# Best Match FSC: ['123', '239', '251', '361']
# Row FSC: ['123', '361']
#
# Best Match FSC: ['536', '549', '424', '514']
# Row FSC: ['623', '606', '600', '264', '128']
#
# Best Match FSC: ['424', '264', '427', '428']
# Row FSC: ['524']
#
# Best Match FSC: ['206', '220']
# Row FSC: ['206']
#
# Best Match FSC: ['202', '98', '214', '104']
# Row FSC: ['114']
#
# Best Match FSC: ['395', '364']
# Row FSC: ['380', '709', '713']
#
# Best Match FSC: ['379']
# Row FSC: ['502']
#
# Best Match FSC: ['427', '204']
# Row FSC: ['524', '252']
#
# Best Match FSC: ['355', '118', '399']
# Row FSC: ['414', '266', '193']
#
# Best Match FSC: ['277', '285', '411', '403']
# Row FSC: ['181', '428']
#
# Best Match FSC: ['149']
# Row FSC: ['106', '252']
#
# Best Match FSC: ['423', '203']
# Row FSC: ['204', '205', '210']
#
# Best Match FSC: ['364', '179', '375', '455']
# Row FSC: ['364']
#
# Best Match FSC: ['340', '174', '361']
# Row FSC: ['235']
#
# Best Match FSC: ['235']
# Row FSC: ['364', '395', '361', '710']
#
# Best Match FSC: ['36']
# Row FSC: ['56', '198', '298', '414', '105']
#
# Best Match FSC: ['604']
# Row FSC: ['604']
#
# Best Match FSC: ['123']
# Row FSC: ['210', '215']
#
# Best Match FSC: ['350', '455']
# Row FSC: ['381', '455']
#
# Best Match FSC: ['323', '363']
# Row FSC: ['328', '307']
#
# Best Match FSC: ['525']
# Row FSC: ['524']
#
# Best Match FSC: ['229']
# Row FSC: ['135', '21', '47', '43', '4']
#
# Best Match FSC: ['428', '427', '229', '527', '524']
# Row FSC: ['528', '524', '525']
#
# Best Match FSC: ['438']
# Row FSC: ['29', '148', '357', '156']
#
# Best Match FSC: ['354', '396']
# Row FSC: ['371', '365', '395', '714']
#
# Best Match FSC: ['24']
# Row FSC: ['248', '24', '40', '428', '211', '281']
#
# Best Match FSC: ['280']
# Row FSC: ['211', '248', '206', '190']
#
# Best Match FSC: ['455', '379', '380', '370']
# Row FSC: ['711', '707']
#
# Best Match FSC: ['73']
# Row FSC: ['356']
#
# Best Match FSC: ['210', '424', '426', '435']
# Row FSC: ['71', '544']
#
# Best Match FSC: ['71', '544']
# Row FSC: ['558']
#
# Best Match FSC: ['214']
# Row FSC: ['219', '204']
#
# Best Match FSC: ['257']
# Row FSC: ['313', '250']
#
# Best Match FSC: ['260']
# Row FSC: ['544', '540', '546', '548', '514']
#
# Best Match FSC: ['560']
# Row FSC: ['71', '548']
#
# Best Match FSC: ['267', '280']
# Row FSC: ['280', '180', '364']
#
# Best Match FSC: ['717']
# Row FSC: ['714']
#
# Best Match FSC: ['208']
# Row FSC: ['585']
#
# Best Match FSC: ['437', '148']
# Row FSC: ['257', '438']
#
# Best Match FSC: ['83', '144', '407']
# Row FSC: ['16', '49', '98', '126', '251', '403', '292', '411']
#
# Best Match FSC: ['345', '349']
# Row FSC: ['422', '324']
#
# Best Match FSC: ['226', '400']
# Row FSC: ['156', '350', '101', '33']
#
# Best Match FSC: ['204']
# Row FSC: ['427']
#
# Best Match FSC: ['179', '178']
# Row FSC: ['369', '360', '386', '364', '381']
#
# Best Match FSC: ['536', '435', '800']
# Row FSC: ['435', '530']
#
# Best Match FSC: ['365']
# Row FSC: ['327']
#
# Best Match FSC: ['536', '435', '530', '514']
# Row FSC: ['195']
#
# Best Match FSC: ['191']
# Row FSC: ['439', '200', '174']
#
# Best Match FSC: ['365']
# Row FSC: ['365', '357']
#
# Best Match FSC: ['436', '422', '4', '358', '52', '424', '128']
# Row FSC: ['137', '52']
#
# Best Match FSC: ['346', '350', '250']
# Row FSC: ['346', '356']
#
# Best Match FSC: ['435', '530']
# Row FSC: ['536', '435']
#
# Best Match FSC: ['560']
# Row FSC: ['260']
#
# Best Match FSC: ['429']
# Row FSC: ['429']
#
# Best Match FSC: ['215', '156']
# Row FSC: ['128', '604']
#
# Best Match FSC: ['429', '252']
# Row FSC: ['29', '429']
#
# Best Match FSC: ['345', '395', '348', '365']
# Row FSC: ['156', '118', '23', '423']
#
# Best Match FSC: ['428']
# Row FSC: ['525']
#
# Best Match FSC: ['350', '40', '362']
# Row FSC: ['362']
#
# Best Match FSC: ['136']
# Row FSC: ['362']
#
# Best Match FSC: ['713']
# Row FSC: ['348', '345', '379', '358', '370']
#
# Best Match FSC: ['395', '380', '364', '371']
# Row FSC: ['711', '365', '710']
#
# Best Match FSC: ['536', '435', '514']
# Row FSC: ['435', '536']
#
# Best Match FSC: ['215']
# Row FSC: ['222', '604', '600', '141', '383']
#
# Best Match FSC: ['435', '549', '560']
# Row FSC: ['530', '424', '514']
#
# Best Match FSC: ['128', '604']
# Row FSC: ['425', '83']
#
# Best Match FSC: ['324', '439']
# Row FSC: ['439']
#
# Best Match FSC: ['204', '29', '15']
# Row FSC: ['159', '202', '203', '196', '208', '110']
#
# Best Match FSC: ['432', '34']
# Row FSC: ['210', '261']
#
# Best Match FSC: ['210', '422', '222', '137', '239']
# Row FSC: ['210']
#
# Best Match FSC: ['252', '508']
# Row FSC: ['53', '156', '206', '426', '427', '428', '118']
#
# Best Match FSC: ['296', '280']
# Row FSC: ['248', '211', '206']
#
# Best Match FSC: ['502', '423']
# Row FSC: ['424']
#
# Best Match FSC: ['166']
# Row FSC: ['165', '277', '285']
#
# Best Match FSC: ['162', '34']
# Row FSC: ['204']
#
# Best Match FSC: ['333']
# Row FSC: ['318']
#
# Best Match FSC: ['424', '514']
# Row FSC: ['536']
#
# Best Match FSC: ['208']
# Row FSC: ['502']
#
# Best Match FSC: ['250', '357', '29']
# Row FSC: ['128', '165', '219']
#
# Best Match FSC: ['424']
# Row FSC: ['502']
#
# Best Match FSC: ['83', '269', '206', '220', 'D 7']
# Row FSC: ['439']
#
# Best Match FSC: ['361', '174', '200', '439']
# Row FSC: ['312', '108', '126']
#
# Best Match FSC: ['209', '250', '426', '436', '324']
# Row FSC: ['198']
#
# Best Match FSC: ['435', '436', '530']
# Row FSC: ['156', '523', '525']
#
# Best Match FSC: ['200', '335']
# Row FSC: ['446', '180', '318']
#
# Best Match FSC: ['369']
# Row FSC: ['347', '399']
#
# Best Match FSC: ['556']
# Row FSC: ['423', '502']
#
# Best Match FSC: ['285']
# Row FSC: ['279']
#
# Best Match FSC: ['204']
# Row FSC: ['558', '564']
#
# Best Match FSC: ['446', '403', '411']
# Row FSC: ['360', '439', '310']
#
# Best Match FSC: ['198']
# Row FSC: ['544']
#
# Best Match FSC: ['332', '375']
# Row FSC: ['357', '364']
#
# Best Match FSC: ['285']
# Row FSC: ['294', '403', '410', '24', '248']
#
# Best Match FSC: ['340', '370', '179', '371']
# Row FSC: ['370']
#
# Best Match FSC: ['364', '29']
# Row FSC: ['364', '239', '47', '118']
#
# Best Match FSC: ['428', '373']
# Row FSC: ['359']
#
# Best Match FSC: ['356', '359']
# Row FSC: ['116', '174', '138', '24']
#
# Best Match FSC: ['514']
# Row FSC: ['424', '514']
#
# Best Match FSC: ['307']
# Row FSC: ['324', '371', '437']
#
# Best Match FSC: ['2', '441', '434']
# Row FSC: ['112', '38', '33']
#
# Best Match FSC: ['75', '148']
# Row FSC: ['148']
#
# Best Match FSC: ['280', '297']
# Row FSC: ['180', '280', '340', '24']
#
# Best Match FSC: ['523', '528', '522']
# Row FSC: ['174', '428', '156', '427']
#
# Best Match FSC: ['324', '29']
# Row FSC: ['361', '307', '340', '337']
#
# Best Match FSC: ['260']
# Row FSC: ['544', '424']
#
# Best Match FSC: ['273', '473', '108']
# Row FSC: ['81', '279']
#
# Best Match FSC: ['354']
# Row FSC: ['358']
#
# Best Match FSC: ['711', '365']
# Row FSC: ['365']
#
# Best Match FSC: ['424', '604', '433']
# Row FSC: ['424']
#
# Best Match FSC: ['324']
# Row FSC: ['29', '236', '431']
#
# Best Match FSC: ['440', '417']
# Row FSC: ['340', '307']
#
# Best Match FSC: ['60', '204', '73']
# Row FSC: ['422', '204', '60', '123']
#
# Best Match FSC: ['326']
# Row FSC: ['365']
#
# Best Match FSC: ['206']
# Row FSC: ['438']
#
# Best Match FSC: ['405', '248', '52', '108']
# Row FSC: ['211', '160']
#
# Best Match FSC: ['62']
# Row FSC: ['423', '252', '106']
#
# Best Match FSC: ['415', '29']
# Row FSC: ['240', '248']
#
# Best Match FSC: ['525']
# Row FSC: ['204']
#
# Best Match FSC: ['330', '363']
# Row FSC: ['423', '518']
#
# Best Match FSC: ['510', '424', '514', '134']
# Row FSC: ['264', '423']
#
# Best Match FSC: ['356']
# Row FSC: ['524', '556', '428', '106', '523']
#
# Best Match FSC: ['701', '73']
# Row FSC: ['340', '343']
#
# Best Match FSC: ['336']
# Row FSC: ['324', '33', '336']
#
# Best Match FSC: ['426', '424']
# Row FSC: ['264', '424', '436']
#
# Best Match FSC: ['439']
# Row FSC: ['357', '257']
#
# Best Match FSC: ['435', '800', '514', '530', '935', '536']
# Row FSC: ['128']
#
# Best Match FSC: ['416']
# Row FSC: ['34']
#
# Best Match FSC: ['424', '514']
# Row FSC: ['514']
#
# Best Match FSC: ['187', '182']
# Row FSC: ['14']
#
# Best Match FSC: ['417', '137', '251']
# Row FSC: ['410', '244', '248']
#
# Best Match FSC: ['177', '251']
# Row FSC: ['366', '220', '422']
#
# Best Match FSC: ['524', '526', '351', '252']
# Row FSC: ['430']
#
# Best Match FSC: ['PLT']
# Row FSC: ['800', 'Plt']
#
# Best Match FSC: ['424', '436']
# Row FSC: ['239']
#
# Best Match FSC: ['74']
# Row FSC: ['477']
#
# Best Match FSC: ['330', '363', '323']
# Row FSC: ['323', '363']
#
# Best Match FSC: ['430', '522']
# Row FSC: ['430']
#
# Best Match FSC: ['446', '112', '428', '156']
# Row FSC: ['446', '29']
#
# Best Match FSC: ['30']
# Row FSC: ['37', '172']
#
# Best Match FSC: ['435']
# Row FSC: ['560', '562']
#
# Best Match FSC: ['260']
# Row FSC: ['424', '433']
#
# Best Match FSC: ['340', '364', '342']
# Row FSC: ['345', '395']
#
# Best Match FSC: ['2', '128']
# Row FSC: ['213']
#
# Best Match FSC: ['356', '359', '250']
# Row FSC: ['73', '340']
#
# Best Match FSC: ['525', '428']
# Row FSC: ['523', '526', '524']
#
# Best Match FSC: ['607', '623']
# Row FSC: ['604', '600', '128', '4']
#
# Best Match FSC: ['206', '606']
# Row FSC: ['403', '24', '240', '354', '279']
#
# Best Match FSC: ['93']
# Row FSC: ['30', '7']
#
# Best Match FSC: ['395', '364']
# Row FSC: ['320', '702']
#
# Best Match FSC: ['339']
# Row FSC: ['439']
#
# Best Match FSC: ['602', '604']
# Row FSC: ['2', '128', '602']
#
# Best Match FSC: ['191']
# Row FSC: ['192', '74']
#
# Best Match FSC: ['524', '86', '102']
# Row FSC: ['174', '427', '428']
#
# Best Match FSC: ['345', '710']
# Row FSC: ['365', '395', '326']
#
# Best Match FSC: ['370', '340', '371']
# Row FSC: ['370', '359', '340']
#
# Best Match FSC: ['428', '359', '362']
# Row FSC: ['313']
#
# Best Match FSC: ['15', '401']
# Row FSC: ['347']
#
# Best Match FSC: ['379']
# Row FSC: ['379']
#
# Best Match FSC: ['546', '514']
# Row FSC: ['548', '71', '564', '560', '260']
#
# Best Match FSC: ['280', '414']
# Row FSC: ['414']
#
# Best Match FSC: ['455']
# Row FSC: ['250', '317', '321', '323']
#
# Best Match FSC: ['136']
# Row FSC: ['375', '331', '329']
#
# Best Match FSC: ['72', '29', '51', '408', '409']
# Row FSC: ['53']
#
# Best Match FSC: ['73']
# Row FSC: ['280', '188']
#
# Best Match FSC: ['55']
# Row FSC: ['310', '29']
#
# Best Match FSC: ['348', '332']
# Row FSC: ['340', '325']
#
# Best Match FSC: ['29', '100', '162']
# Row FSC: ['112', '223']
#
# Best Match FSC: ['70']
# Row FSC: ['70']
#
# Best Match FSC: ['210', '426', '530']
# Row FSC: ['430']
#
# Best Match FSC: ['534']
# Row FSC: ['428', '524', '523']
#
# Best Match FSC: ['372']
# Row FSC: ['372']
#
# Best Match FSC: ['210', '423', '502']
# Row FSC: ['502']
#
# Best Match FSC: ['342', '340']
# Row FSC: ['330', '375', '455']
#
# Best Match FSC: ['427']
# Row FSC: ['216', '438', '204']
#
# Best Match FSC: ['44', '568']
# Row FSC: ['203', '549', '560', '568']
#
# Best Match FSC: ['23', '204']
# Row FSC: ['260', '536']
#
# Best Match FSC: ['42', '89']
# Row FSC: ['239']
#
# Best Match FSC: ['16', '220']
# Row FSC: ['215']
#
# Best Match FSC: ['348', '345', '455', '364', '395', '709']
# Row FSC: ['463', '273']
#
# Best Match FSC: ['424', '514']
# Row FSC: ['166', '507']
#
# Best Match FSC: ['106']
# Row FSC: ['427', '437', '118', '134']
#
# Best Match FSC: ['524', '523']
# Row FSC: ['239', '285', '134']
#
# Best Match FSC: ['435', '536']
# Row FSC: ['424']
#
# Best Match FSC: ['395']
# Row FSC: ['395', '364', '359']
#
# Best Match FSC: ['435', '536']
# Row FSC: ['536', '435']
#
# Best Match FSC: ['165', '236', '237']
# Row FSC: ['236', '62', '165', '374']
#
# Best Match FSC: ['310']
# Row FSC: ['16', '190', '280', '403']
#
# Best Match FSC: ['211', '206']
# Row FSC: ['360']
#
# Best Match FSC: ['52', '428']
# Row FSC: ['52', '98']
#
# Best Match FSC: ['455', '379']
# Row FSC: ['455', '379']
#
# Best Match FSC: ['356']
# Row FSC: ['356', '329', '250', '600']
#
# Best Match FSC: ['382', '356', '283']
# Row FSC: ['367', '342']
#
# Best Match FSC: ['101', '156']
# Row FSC: ['299', '405']
#
# Best Match FSC: ['29']
# Row FSC: ['528', '264']
#
# Best Match FSC: ['364', '219']
# Row FSC: ['172', '180', '364']
#
# Best Match FSC: ['604']
# Row FSC: ['241']
#
# Best Match FSC: ['149', '264', '86']
# Row FSC: ['252']
#
# Best Match FSC: ['342']
# Row FSC: ['367', '702', '342', '356']
#
# Best Match FSC: ['285', '166', '175']
# Row FSC: ['166', '175', '89', '102']
#
# Best Match FSC: ['606', '112', '604', '223']
# Row FSC: ['600', '606']
#
# Best Match FSC: ['426', '425', '452']
# Row FSC: ['60', '251']
#
# Best Match FSC: ['424']
# Row FSC: ['273', '482', '73']
#
# Best Match FSC: ['296', '312', '49', '16', '188']
# Row FSC: ['451']
#
# Best Match FSC: ['269']
# Row FSC: ['414', '294', '901']
#
# Best Match FSC: ['382', '345', '348']
# Row FSC: ['356', '250', '430', '355']
#
# Best Match FSC: ['198']
# Row FSC: ['279']
#
# Best Match FSC: ['430']
# Row FSC: ['333', '343']
#
# Best Match FSC: ['358', '360', '369']
# Row FSC: ['310']
#
# Best Match FSC: ['437']
# Row FSC: ['438']
#
# Best Match FSC: ['59', '474', '198']
# Row FSC: ['15']
#
# Best Match FSC: ['430']
# Row FSC: ['430']
#
# Best Match FSC: ['435', '436', '395', '364']
# Row FSC: ['250']
#
# Best Match FSC: ['405']
# Row FSC: ['438', '414', '141', '280']
#
# Best Match FSC: ['710']
# Row FSC: ['55']
#
# Best Match FSC: ['251']
# Row FSC: ['415']
#
# Best Match FSC: ['374', '73', '165']
# Row FSC: ['250']
#
# Best Match FSC: ['51', '411']
# Row FSC: ['424', '528', '128', '525', '514']
#
# Best Match FSC: ['427', '428', '148', '205']
# Row FSC: ['29', '280', '188', '74']
#
# Best Match FSC: ['99', 'D 7', '30']
# Row FSC: ['242', '190', '150']
#
# Best Match FSC: ['502', '423']
# Row FSC: ['205', '204', '210']
#
# Best Match FSC: ['604']
# Row FSC: ['99', '211']
#
# Best Match FSC: ['257', '174', '361']
# Row FSC: ['128', '607', '29', '340']
#
# Best Match FSC: ['364', '395']
# Row FSC: ['327', '323']
#
# Best Match FSC: ['350', '343', '52', '427']
# Row FSC: ['307', '318', '15']
#
# Best Match FSC: ['704']
# Row FSC: ['60', '415']
#
# Best Match FSC: ['224']
# Row FSC: ['2', '351']
#
# Best Match FSC: ['203', '210', '568']
# Row FSC: ['564', '423']
#
# Best Match FSC: ['381']
# Row FSC: ['128']
#
# Best Match FSC: ['530', '514']
# Row FSC: ['564', '502']
#
# Best Match FSC: ['438']
# Row FSC: ['438']
#
# Best Match FSC: ['188', '267', '280']
# Row FSC: ['68']
#
# Best Match FSC: ['355', '358']
# Row FSC: ['395', '712']
#
# Best Match FSC: ['90', '51']
# Row FSC: ['83', '241']
#
# Best Match FSC: ['260']
# Row FSC: ['428', '523', '524', '252']
#
# Best Match FSC: ['318', '432', '34']
# Row FSC: ['714', '360']
#
# Best Match FSC: ['362']
# Row FSC: ['211', '248']
#
# Best Match FSC: ['260', '548', '549']
# Row FSC: ['502']
#
# Best Match FSC: ['15']
# Row FSC: ['15']
#
# Best Match FSC: ['395', '345', '348']
# Row FSC: ['358', '348', '386']
#
# Best Match FSC: ['285', '156', '604', '138']
# Row FSC: ['623', '606']
#
# Best Match FSC: ['135']
# Row FSC: ['433', '600', '128', '383']
#
# Best Match FSC: ['134', '252']
# Row FSC: ['451']
#
# Best Match FSC: ['438', '257']
# Row FSC: ['257', '438']
#
# Best Match FSC: ['428', '427']
# Row FSC: ['369', '360']
#
# Best Match FSC: ['425', '366', '264']
# Row FSC: ['360', '384']
#
# Best Match FSC: ['210', '134']
# Row FSC: ['162', '209']
#
# Best Match FSC: ['426']
# Row FSC: ['137', '4', '251']
#
# Best Match FSC: ['455', '375', '331']
# Row FSC: ['315', '358']
#
# Best Match FSC: ['128']
# Row FSC: ['250', '62', '340', '317']
#
# Best Match FSC: ['524', '86', '102']
# Row FSC: ['206', '229']
#
# Best Match FSC: ['346']
# Row FSC: ['360', '714']
#
# Best Match FSC: ['206', '150']
# Row FSC: ['83', '831']
#
# Best Match FSC: ['341', '364']
# Row FSC: ['248', '439', '174', '191', '52']
#
# Best Match FSC: ['73', '250', '356']
# Row FSC: ['427', '118', '239']
#
# Best Match FSC: ['424']
# Row FSC: ['355', '141', '222']
#
# Best Match FSC: ['71', '544']
# Row FSC: ['560', '562']
#
# Best Match FSC: ['81', '403']
# Row FSC: ['244', '74', '292']
#
# Best Match FSC: ['229', '206']
# Row FSC: ['206', '24', '140']
#
# Best Match FSC: ['355']
# Row FSC: ['250']
#
# Best Match FSC: ['315', '333', '313']
# Row FSC: ['381', '395']
#
# Best Match FSC: ['430']
# Row FSC: ['430']
#
# Best Match FSC: ['313', '339']
# Row FSC: ['285', '138', '251']
#
# Best Match FSC: ['264']
# Row FSC: ['426']
#
# Best Match FSC: ['800', '435', '536']
# Row FSC: ['424']
#
# Best Match FSC: ['16', '190', '280']
# Row FSC: ['280', '224', '248', 'D34']
#
# Best Match FSC: ['206', '132', '225']
# Row FSC: ['42', '89']
#
# Best Match FSC: ['399']
# Row FSC: ['523', '106', '428']
#
# Best Match FSC: ['501', '106']
# Row FSC: ['426']
#
# Best Match FSC: ['327']
# Row FSC: ['307', '330', '328']
#
# Best Match FSC: ['430', '313', '427']
# Row FSC: ['372']
#
# Best Match FSC: ['435', '530']
# Row FSC: ['530', '435']
#
# Best Match FSC: ['385', '356', '359']
# Row FSC: ['359', '372']
#
# Best Match FSC: ['544', '540']
# Row FSC: ['435', '536', '800']
#
# Best Match FSC: ['116']
# Row FSC: ['446', '362']
#
# Best Match FSC: ['401']
# Row FSC: ['600']
#
# Best Match FSC: ['315', '340']
# Row FSC: ['62']
#
# Best Match FSC: ['430']
# Row FSC: ['427', '96', '29', '430']
#
# Best Match FSC: ['473', '525']
# Row FSC: ['366', '220', '222']
#
# Best Match FSC: ['623']
# Row FSC: ['29']
#
# Best Match FSC: ['355', '358', '346']
# Row FSC: ['370', '710']
#
# Best Match FSC: ['504', '544']
# Row FSC: ['252']
#
# Best Match FSC: ['175']
# Row FSC: ['74']
#
# Best Match FSC: ['446', '403', '411']
# Row FSC: ['606', '128', '403']
#
# Best Match FSC: ['29', '228', '219']
# Row FSC: ['414', '172', '280', '296', '180']
#
# Best Match FSC: ['348']
# Row FSC: ['355', '430', '250', '356', '359']
#
# Best Match FSC: ['375']
# Row FSC: ['343']
#
# Best Match FSC: ['222', '141', '73']
# Row FSC: ['355', '396', '399']
#
# Best Match FSC: ['220', '285', '277']
# Row FSC: ['285']
#
# Best Match FSC: ['365']
# Row FSC: ['395', '365', '711']
#
# Best Match FSC: ['424']
# Row FSC: ['148', '427', '428']
#
# Best Match FSC: ['148', '357', '437']
# Row FSC: ['73', '374']
#
# Best Match FSC: ['187', '182']
# Row FSC: ['297', '187', '180']
#
# Best Match FSC: ['180', '317', '123']
# Row FSC: ['369', '713']
#
# Best Match FSC: ['530', '514']
# Row FSC: ['514', '435', '536', '530']
#
# Best Match FSC: ['164']
# Row FSC: ['53', '156']
#
# Best Match FSC: ['106', '260']
# Row FSC: ['166']
#
# Best Match FSC: ['382']
# Row FSC: ['395', '340']
#
# Best Match FSC: ['405', '52']
# Row FSC: ['228', '219', '138']
#
# Best Match FSC: ['257']
# Row FSC: ['330']
#
# Best Match FSC: ['428', '430', '252', '399']
# Row FSC: ['350']
#
# Best Match FSC: ['273']
# Row FSC: ['473']
#
# Best Match FSC: ['430']
# Row FSC: ['428']
#
# Best Match FSC: ['482', '606', '128', 'D21', 'D24', 'D29']
# Row FSC: ['212', '414', '29', '254', '296', '180', '280']
#
# Best Match FSC: ['239', '222']
# Row FSC: ['429', '29']
#
# Best Match FSC: ['438']
# Row FSC: ['438', '148']
#
# Best Match FSC: ['165', '236', '237']
# Row FSC: ['29', '137', '219', '228', '138']
#
# Best Match FSC: ['435']
# Row FSC: ['530', '514', '424']
#
# Best Match FSC: ['182']
# Row FSC: ['280', '242', '297', '244', '180']
#
# Best Match FSC: ['604']
# Row FSC: ['128', '351', '606']
#
# Best Match FSC: ['248', '211', '108']
# Row FSC: ['37', '299', '175', '173']
#
# Best Match FSC: ['526']
# Row FSC: ['514', '548']
#
# Best Match FSC: ['380', '371']
# Row FSC: ['395', '370']
#
# Best Match FSC: ['260', '210']
# Row FSC: ['136']
#
# Best Match FSC: ['546']
# Row FSC: ['106']
#
# Best Match FSC: ['148', '437']
# Row FSC: ['427', '204', '118']
#
# Best Match FSC: ['430']
# Row FSC: ['350']
#
# Best Match FSC: ['248', '211', '24']
# Row FSC: ['83', '33', '116']
#
# Best Match FSC: ['330', '363', '323']
# Row FSC: ['307']
#
# Best Match FSC: ['399', '276', '346', '347', '400']
# Row FSC: ['101']
#
# Best Match FSC: ['435', '530']
# Row FSC: ['536', '435', '800', '935']
#
# Best Match FSC: ['257']
# Row FSC: ['437', '148']
#
# Best Match FSC: ['260', '204']
# Row FSC: ['372']
#
# Best Match FSC: ['211', '250', '271']
# Row FSC: ['53', '156']
#
# Best Match FSC: ['55', '261']
# Row FSC: ['422', '60', '502', '428']
#
# Best Match FSC: ['136', '427', '428']
# Row FSC: ['338', '361', '335', '174', '339']
#
# Best Match FSC: ['564']
# Row FSC: ['544']
#
# Best Match FSC: ['554', '562']
# Row FSC: ['528', '264']
#
# Best Match FSC: ['530', '435']
# Row FSC: ['435', '536', '935']
#
# Best Match FSC: ['73']
# Row FSC: ['273', '173', '145', '174', '74']
#
# Best Match FSC: ['428', '52']
# Row FSC: ['239']
#
# Best Match FSC: ['562', '127', '536']
# Row FSC: ['435', '260', '195']
#
# Best Match FSC: ['72', '192', '29']
# Row FSC: ['354', '34', '432', '96', '430', '355']
#
# Best Match FSC: ['360']
# Row FSC: ['360']
#
# Best Match FSC: ['204', '205']
# Row FSC: ['427', '204']
#
# Best Match FSC: ['366', '426', '99']
# Row FSC: ['83', '409', '91', '241', '100']
#
# Best Match FSC: ['273', '35']
# Row FSC: ['428', '15', '101', '144']
#
# Best Match FSC: ['52', '405', '135', '5', '404', '210']
# Row FSC: ['296']
#
# Best Match FSC: ['277', '384']
# Row FSC: ['403', '285']
#
# Best Match FSC: ['198', '308']
# Row FSC: ['152']
#
# Best Match FSC: ['359']
# Row FSC: ['399', '356']
#
# Best Match FSC: ['70', '160', '292']
# Row FSC: ['83']
#
# Best Match FSC: ['418']
# Row FSC: ['418', '277']
#
# Best Match FSC: ['318', '363', '180', '190']
# Row FSC: ['361', '257']
#
# Best Match FSC: ['430']
# Row FSC: ['430']
#
# Best Match FSC: ['514', '530', '435', '424']
# Row FSC: ['435', '514', '549', '536']
#
# Best Match FSC: ['354']
# Row FSC: ['369', '359']
#
# Best Match FSC: ['248', '182', '440']
# Row FSC: ['92', '417', '184', '74', '384']
#
# Best Match FSC: ['206']
# Row FSC: ['346', '29', '347', '222']
#
# Best Match FSC: ['260']
# Row FSC: ['544']
#
# Best Match FSC: ['395', '713', '711']
# Row FSC: ['128', '604', '364']
#
# Best Match FSC: ['606', '128']
# Row FSC: ['623']
#
# Best Match FSC: ['428']
# Row FSC: ['525']
#
# Best Match FSC: ['424', '585', '260']
# Row FSC: ['435']
#
# Best Match FSC: ['Plt']
# Row FSC: ['36', '12']
#
# Best Match FSC: ['424']
# Row FSC: ['549', '514']
#
# Best Match FSC: ['260']
# Row FSC: ['106', '208', '252', '260']
#
# Best Match FSC: ['324', '333']
# Row FSC: ['363', '336', '219', '60']
#
# Best Match FSC: ['294', '279']
# Row FSC: ['15', '601']
#
# Best Match FSC: ['710', '709', '707']
# Row FSC: ['395', '711']
#
# Best Match FSC: ['403', '144']
# Row FSC: ['70']
#
# Best Match FSC: ['518']
# Row FSC: ['526']
#
# Best Match FSC: ['204']
# Row FSC: ['250', '356']
#
# Best Match FSC: ['530', '536', '435']
# Row FSC: ['435']
#
# Best Match FSC: ['426']
# Row FSC: ['435', '536', '800']
#
# Best Match FSC: ['156']
# Row FSC: ['34', '432', '49']
#
# Best Match FSC: ['273']
# Row FSC: ['273', '446']
#
# Best Match FSC: ['260', '204', '427']
# Row FSC: ['525']
#
# Best Match FSC: ['250', '126', '356']
# Row FSC: ['318', '74', '33', '356', '359', '250']
#
# Best Match FSC: ['482', '135']
# Row FSC: ['242', '156']
#
# Best Match FSC: ['524', '526']
# Row FSC: ['430']
#
# Best Match FSC: ['312', '211']
# Row FSC: ['705', '235', '380', '150']
#
# Best Match FSC: ['604', '422', '128']
# Row FSC: ['210', '429']
#
# Best Match FSC: ['83']
# Row FSC: ['415', '29', '403']
#
# Best Match FSC: ['273']
# Row FSC: ['369']
#
# Best Match FSC: ['431']
# Row FSC: ['525', '428', '528', '264']
#
# Best Match FSC: ['252', '313']
# Row FSC: ['502', '562']
#
# Best Match FSC: ['220', '206', '108']
# Row FSC: ['135', '403', '405', '52']
#
# Best Match FSC: ['148', '437']
# Row FSC: ['164', '75']
#
# Best Match FSC: ['340', '180']
# Row FSC: ['174']
#
# Best Match FSC: ['362']
# Row FSC: ['356', '359']
#
# Best Match FSC: ['514']
# Row FSC: ['55', '96', '454', '95']
#
# Best Match FSC: ['514', '544']
# Row FSC: ['248']
#
# Best Match FSC: ['252', '209', '260', '568']
# Row FSC: ['524', '75', '241']
#
# Best Match FSC: ['428']
# Row FSC: ['8', '68', '206', '28']
#
# Best Match FSC: ['192', '74']
# Row FSC: ['198']
#
# Best Match FSC: ['363']
# Row FSC: ['323']
#
# Best Match FSC: ['192', '464']
# Row FSC: ['318', '340', '361']
#
# Best Match FSC: ['510', '424', '514', '134']
# Row FSC: ['156', '252', '427']
#
# Best Match FSC: ['439']
# Row FSC: ['340', '200', '70']
#
# Best Match FSC: ['502', '208']
# Row FSC: ['260', '252']
#
# Best Match FSC: ['4']
# Row FSC: ['4']
#
# Best Match FSC: ['257', '437']
# Row FSC: ['438', '257']
#
# Best Match FSC: ['380']
# Row FSC: ['234', '434', '283']
#
# Best Match FSC: ['337']
# Row FSC: ['411', '175']
#
# Best Match FSC: ['192']
# Row FSC: ['57']
#
# Best Match FSC: ['52', '160']
# Row FSC: ['428', '442']
#
# Best Match FSC: ['250', '358']
# Row FSC: ['358', '382']
#
# Best Match FSC: ['371', '364', '324']
# Row FSC: ['438']
#
# Best Match FSC: ['236', '165', '110', '122', '237']
# Row FSC: ['219']
#
# Best Match FSC: ['704']
# Row FSC: ['210', '436', '435']
#
# Best Match FSC: ['194']
# Row FSC: ['198', '271', '414']
#
# Best Match FSC: ['214']
# Row FSC: ['364']
#
# Best Match FSC: ['364', '395']
# Row FSC: ['381', '73', '128', '439']
#
# Best Match FSC: ['285', '166', '175']
# Row FSC: ['137']
#
# Best Match FSC: ['128']
# Row FSC: ['119', '222', '60']
#
# Best Match FSC: ['355', '356']
# Row FSC: ['356', '350']
#
# Best Match FSC: ['438', '257']
# Row FSC: ['437', '257']
#
# Best Match FSC: ['455', '327']
# Row FSC: ['455']
#
# Best Match FSC: ['428']
# Row FSC: ['526']
#
# Best Match FSC: ['60', '290', '417']
# Row FSC: ['343']
#
# Best Match FSC: ['376']
# Row FSC: ['494', '210', '422']
#
# Best Match FSC: ['714', '703']
# Row FSC: ['707', '364']
#
# Best Match FSC: ['425', '99', '15', '198']
# Row FSC: ['72']
#
# Best Match FSC: ['438']
# Row FSC: ['438', '134', '427']
#
# Best Match FSC: ['524', '525', '528', '427']
# Row FSC: ['428', '525']
#
# Best Match FSC: ['331', '341', '327', '708']
# Row FSC: ['329', '325']
#
# Best Match FSC: ['512', '549', '560', '562']
# Row FSC: ['568', '252']
#
# Best Match FSC: ['428']
# Row FSC: ['264', '425']
#
# Best Match FSC: ['330']
# Row FSC: ['358']
#
# Best Match FSC: ['424', '222']
# Row FSC: ['514', '568', '424']
#
# Best Match FSC: ['106']
# Row FSC: ['136']
#
# Best Match FSC: ['374', '99', '219', '364']
# Row FSC: ['222']
#
# Best Match FSC: ['43']
# Row FSC: ['219', '174']
#
# Best Match FSC: ['192', '29']
# Row FSC: ['418', '55']
#
# Best Match FSC: ['310', '318']
# Row FSC: ['73', '81']
#
# Best Match FSC: ['331']
# Row FSC: ['365']
#
# Best Match FSC: ['360', '371']
# Row FSC: ['375', '329', '327', '371']
#
# Best Match FSC: ['307', '323', '327']
# Row FSC: ['379', '370']
#
# Best Match FSC: ['260', '548']
# Row FSC: ['521', '528']
#
# Best Match FSC: ['522', '523', '204']
# Row FSC: ['324', '522', '106', '264', '257', '252', '423', '427', '204', '438']
#
# Best Match FSC: ['273', '52']
# Row FSC: ['361', '206', '211', '174']
#
# Best Match FSC: ['138']
# Row FSC: ['137']
#
# Best Match FSC: ['192']
# Row FSC: ['70', '292']
#
# Best Match FSC: ['43', '40', '446']
# Row FSC: ['43']
#
# Best Match FSC: ['405']
# Row FSC: ['47', 'D 6', '211', '248']
#
# Best Match FSC: ['206']
# Row FSC: ['206', '220']
#
# Best Match FSC: ['248', '396']
# Row FSC: ['37', '172', '198', '180', '248']
#
# Best Match FSC: ['417', '92', '184']
# Row FSC: ['222', '251', '220']
#
# Best Match FSC: ['335']
# Row FSC: ['206', '190', '220']
#
# Best Match FSC: ['297', '108', '248']
# Row FSC: ['182', '52']
#
# Best Match FSC: ['280', '298']
# Row FSC: ['180', '280']
#
# Best Match FSC: ['106']
# Row FSC: ['429', '427']
#
# Best Match FSC: ['435', '436', '530']
# Row FSC: ['414']
#
# Best Match FSC: ['204']
# Row FSC: ['205', '427']
#
# Best Match FSC: ['162']
# Row FSC: ['430', '8']
#
# Best Match FSC: ['439']
# Row FSC: ['439']
#
# Best Match FSC: ['410', '188', '248']
# Row FSC: ['160']
#
# Best Match FSC: ['370']
# Row FSC: ['324', '371', '29']
#
# Best Match FSC: ['428', '359']
# Row FSC: ['346', '358']
#
# Best Match FSC: ['257', '438']
# Row FSC: ['623', '128', '604', '424', '428']
#
# Best Match FSC: ['102']
# Row FSC: ['116', '324', '335']
#
# Best Match FSC: ['438', '148', '117']
# Row FSC: ['360']
#
# Best Match FSC: ['5', '267']
# Row FSC: ['220']
#
# Best Match FSC: ['395', '345']
# Row FSC: ['358', '382']
#
# Best Match FSC: ['296', '248', '24']
# Row FSC: ['294', '206', '211', '224', '280']
#
# Best Match FSC: ['365']
# Row FSC: ['364']
#
# Best Match FSC: ['96', '252']
# Row FSC: ['106', '260']
#
# Best Match FSC: ['182']
# Row FSC: ['200', '361', '335', '337']
#
# Best Match FSC: ['430', '378']
# Row FSC: ['228', '29', '427']
#
# Best Match FSC: ['365']
# Row FSC: ['707', '364', '342', '345', '705']
#
# Best Match FSC: ['365']
# Row FSC: ['395', '364', '365', '371']
#
# Best Match FSC: ['307', '328']
# Row FSC: ['364', '395']
#
# Best Match FSC: ['15']
# Row FSC: ['210']
#
# Best Match FSC: ['604']
# Row FSC: ['604', '128']
#
# Best Match FSC: ['435', '536']
# Row FSC: ['436', '422']
#
# Best Match FSC: ['436', '435']
# Row FSC: ['250', '560']
#
# Best Match FSC: ['521']
# Row FSC: ['252']
#
# Best Match FSC: ['PLT']
# Row FSC: ['PLT']
#
# Best Match FSC: ['365']
# Row FSC: ['235', '186', '312']
#
# Best Match FSC: ['210', '422']
# Row FSC: ['194', '100', '209']
#
# Best Match FSC: ['331', '332', '328']
# Row FSC: ['315']
#
# Best Match FSC: ['524']
# Row FSC: ['260', '424']
#
# Best Match FSC: ['363', '323', '333']
# Row FSC: ['363']
#
# Best Match FSC: ['430', '438']
# Row FSC: ['430', '525']
#
# Best Match FSC: ['260', '560']
# Row FSC: ['530', '424']
#
# Best Match FSC: ['269', '403', '405', '114', '901', '414']
# Row FSC: ['494', '364', '340', '210']
#
# Best Match FSC: ['248', '297', '403']
# Row FSC: ['219']
#
# Best Match FSC: ['428', '360', '369']
# Row FSC: ['264', '428']
#
# Best Match FSC: ['318']
# Row FSC: ['315', '323', '307']
#
# Best Match FSC: ['110', '432']
# Row FSC: ['425']
#
# Best Match FSC: ['292', '312']
# Row FSC: ['36', '602']
#
# Best Match FSC: ['709']
# Row FSC: ['345', '709']
#
# Best Match FSC: ['385']
# Row FSC: ['343', '343']
#
# Best Match FSC: ['705', '713']
# Row FSC: ['379', '340']
#
# Best Match FSC: ['379']
# Row FSC: ['395', '714']
#
# Best Match FSC: ['62']
# Row FSC: ['15', '2']
#
# Best Match FSC: ['424']
# Row FSC: ['564']
#
# Best Match FSC: ['192', '29']
# Row FSC: ['52', '98']
#
# Best Match FSC: ['138']
# Row FSC: ['128']
#
# Best Match FSC: ['132', '424', '401', '252', '156', '204', '159', '427']
# Row FSC: ['424']
#
# Best Match FSC: ['17']
# Row FSC: ['452']
#
# Best Match FSC: ['128', '73', '342', '310', '367']
# Row FSC: ['354']
#
# Best Match FSC: ['73']
# Row FSC: ['222', '128']
#
# Best Match FSC: ['362']
# Row FSC: ['250', '313']
#
# Best Match FSC: ['430']
# Row FSC: ['65']
#
# Best Match FSC: ['166']
# Row FSC: ['368', '446']
#
# Best Match FSC: ['19']
# Row FSC: ['493', '226']
#
# Best Match FSC: ['128']
# Row FSC: ['435', '436']
#
# Best Match FSC: ['313', '335']
# Row FSC: ['29', '429', '419']
#
# Best Match FSC: ['73']
# Row FSC: ['340', '358', '73', '244', '102', '356', '250', '348']
#
# Best Match FSC: ['415']
# Row FSC: ['123', '184', '165']
#
# Best Match FSC: ['328', '370', '371', '375', '380']
# Row FSC: ['370', '455']
#
# Best Match FSC: ['210', '156', '264', '428']
# Row FSC: ['428', '426', '229']
#
# Best Match FSC: ['701', '180', '60', '290', '318']
# Row FSC: ['123', '364']
#
# Best Match FSC: ['514']
# Row FSC: ['424']
#
# Best Match FSC: ['250', '356']
# Row FSC: ['250']
#
# Best Match FSC: ['364']
# Row FSC: ['364']
#
# Best Match FSC: ['156', '134']
# Row FSC: ['47']
#
# Best Match FSC: ['250']
# Row FSC: ['128', '606']
#
# Best Match FSC: ['415', '416']
# Row FSC: ['220', '108', '410', '248', '296']
#
# Best Match FSC: ['381', '379']
# Row FSC: ['355']
#
# Best Match FSC: ['210', '48', '435']
# Row FSC: ['431', '239']
#
# Best Match FSC: ['60', '418']
# Row FSC: ['72']
#
# Best Match FSC: ['260']
# Row FSC: ['260', '208']
#
# Best Match FSC: ['360', '220']
# Row FSC: ['335', '355', '118', '29']
#
# Best Match FSC: ['307']
# Row FSC: ['365']
#
# Best Match FSC: ['437', '148']
# Row FSC: ['437']
#
# Best Match FSC: ['528', '524']
# Row FSC: ['510', '252', '134', '106']
#
# Best Match FSC: ['427']
# Row FSC: ['423', '429']
#
# Best Match FSC: ['405', '166', '114']
# Row FSC: ['252']
#
# Best Match FSC: ['395', '340', '370', '326']
# Row FSC: ['307', '361']
#
# Best Match FSC: ['250']
# Row FSC: ['280']
#
# Best Match FSC: ['215', '156', '428']
# Row FSC: ['427']
#
# Best Match FSC: ['260']
# Row FSC: ['546', '504', '514']
#
# Best Match FSC: ['427', '356']
# Row FSC: ['206', '434', '353', '350']
#
# Best Match FSC: ['376', '165']
# Row FSC: []
#
# Best Match FSC: ['441', '116', '405', '128', '340']
# Row FSC: ['324', '364', '377']
#
# Best Match FSC: ['126']
# Row FSC: ['43', '138']
#
# Best Match FSC: ['252', '8', '510']
# Row FSC: ['57']
#
# Best Match FSC: ['60', '431', '239']
# Row FSC: ['110', '431']
#
# Best Match FSC: ['33', '901', '74']
# Row FSC: ['318', '901', '200']
#
# Best Match FSC: ['44']
# Row FSC: ['106', '208', '210', '405', '502']
#
# Best Match FSC: ['191']
# Row FSC: ['188']
#
# Best Match FSC: ['385', '372']
# Row FSC: ['431', '239', '60']
#
# Best Match FSC: ['72', '29']
# Row FSC: ['29']
#
# Best Match FSC: ['8', '427', '435', '252']
# Row FSC: ['526', '528']
#
# Best Match FSC: ['297', '108', '248']
# Row FSC: ['144', '59']
#
# Best Match FSC: ['310', '333']
# Row FSC: ['333', '310', '29']
#
# Best Match FSC: ['220', '73']
# Row FSC: ['428', '5', '264']
#
# Best Match FSC: ['363']
# Row FSC: ['345', '348']
#
# Best Match FSC: ['354']
# Row FSC: ['354']
#
# Best Match FSC: ['135']
# Row FSC: ['296', '180']
#
# Best Match FSC: ['540', '514']
# Row FSC: ['549', '514']
#
# Best Match FSC: ['257', '438', '365']
# Row FSC: ['257']
#
# Best Match FSC: ['360']
# Row FSC: ['357', '250']
#
# Best Match FSC: ['364', '179', '375', '455']
# Row FSC: ['364', '375', '327', '348', '324']
#
# Best Match FSC: ['425', '264']
# Row FSC: ['204']
#
# Best Match FSC: ['528', '525', '523', '106', '427']
# Row FSC: ['528', '527', '525', '522']
#
# Best Match FSC: ['257']
# Row FSC: ['181', '381']
#
# Best Match FSC: ['333']
# Row FSC: ['358', '379', '375']
#
# Best Match FSC: ['474']
# Row FSC: ['33', '356']
#
# Best Match FSC: ['711', '714', '709', '710']
# Row FSC: ['370', '455', '395']
#
# Best Match FSC: ['542', '546']
# Row FSC: ['91', '92']
#
# Best Match FSC: ['385']
# Row FSC: ['2', '428']
#
# Best Match FSC: ['368']
# Row FSC: ['315']
#
# Best Match FSC: ['424']
# Row FSC: ['424']
#
# Best Match FSC: ['363', '323', '361']
# Row FSC: ['429', '324', '340', '320']
#
# Best Match FSC: ['73']
# Row FSC: ['73', '138', '220']
#
# Best Match FSC: ['44', '568']
# Row FSC: ['528', '526']
#
# Best Match FSC: ['166', '523']
# Row FSC: ['252', '260', '524', '568', '564']
#
# Best Match FSC: ['273', '16']
# Row FSC: ['104', '37', '404', 'D12', 'D15', '81']
#
# Best Match FSC: ['502', '423']
# Row FSC: ['364', '340']
#
# Best Match FSC: ['318']
# Row FSC: ['250', '356', '340']
#
# Best Match FSC: ['252', '544']
# Row FSC: ['252']
#
# Best Match FSC: ['252', '44']
# Row FSC: ['123', '74']
#
# Best Match FSC: ['395', '380', '364', '371']
# Row FSC: ['187']
#
# Best Match FSC: ['52', '264']
# Row FSC: ['73']
#
# Best Match FSC: ['546', '544', '514']
# Row FSC: ['502']
#
# Best Match FSC: ['62', '237', '60']
# Row FSC: ['137', '175', '340']
#
# Best Match FSC: ['514', '424']
# Row FSC: ['427', '428', '96']
#
# Best Match FSC: ['267', '280']
# Row FSC: ['134', '68']
#
# Best Match FSC: ['428', '430']
# Row FSC: ['360', '369']
#
# Best Match FSC: ['439']
# Row FSC: ['335', '200']
#
# Best Match FSC: ['210', '562']
# Row FSC: ['423', '75']
#
# Best Match FSC: ['369', '360']
# Row FSC: ['422', '435']
#
# Best Match FSC: ['371', '370']
# Row FSC: ['364', '395', '711', '709', '710']
#
# Best Match FSC: ['330']
# Row FSC: ['326']
#
# Best Match FSC: ['365', '371']
# Row FSC: ['365']
#
# Best Match FSC: ['424']
# Row FSC: ['427', '75', '428', '210']
#
# Best Match FSC: ['370', '375', '379', '307', '328']
# Row FSC: ['55', '210']
#
# Best Match FSC: ['505', '623', '106']
# Row FSC: ['428', '427', '360', '252']
#
# Best Match FSC: ['546', '514']
# Row FSC: ['514', '549']
#
# Best Match FSC: ['210', '159', '34']
# Row FSC: ['203', '202', '159', '210']
#
# Best Match FSC: ['215', '220', '222']
# Row FSC: ['222']
#
# Best Match FSC: ['339']
# Row FSC: ['343']
#
# Best Match FSC: ['2']
# Row FSC: ['296']
#
# Best Match FSC: ['198']
# Row FSC: ['192', '74']
#
# Best Match FSC: ['128']
# Row FSC: ['73', '210', '324', '340', '55']
#
# Best Match FSC: ['428']
# Row FSC: ['528', '428', '349']
#
# Best Match FSC: ['395', '364']
# Row FSC: ['514']
#
# Best Match FSC: ['701', '364']
# Row FSC: ['73']
#
# Best Match FSC: ['126', '122', '237', '202']
# Row FSC: ['62']
#
# Best Match FSC: ['701', '244']
# Row FSC: ['128']
#
# Best Match FSC: ['72']
# Row FSC: ['160']
#
# Best Match FSC: ['339']
# Row FSC: ['339', '29', '174']
#
# Best Match FSC: ['29', '425', '76']
# Row FSC: ['378']
#
# Best Match FSC: ['136', '357']
# Row FSC: ['29', '429', '156', '822']
#
# Best Match FSC: ['435', '422']
# Row FSC: ['15', '128', '173', '51', '418', '73']
#
# Best Match FSC: ['135']
# Row FSC: ['219', '99']
#
# Best Match FSC: ['71']
# Row FSC: ['435']
#
# Best Match FSC: ['73']
# Row FSC: ['604', '607', '424']
#
# Best Match FSC: ['333']
# Row FSC: ['359', '370']
#
# Best Match FSC: ['560', '514', '549']
# Row FSC: ['514', '552']
#
# Best Match FSC: ['364', '395', '264', '425', '156']
# Row FSC: ['374']
#
# Best Match FSC: ['369', '360', '365', '428']
# Row FSC: ['428']
#
# Best Match FSC: ['206', '229']
# Row FSC: ['206']
#
# Best Match FSC: ['219', '34', '137', '251']
# Row FSC: ['48', '165', '122', '55']
#
# Best Match FSC: ['330']
# Row FSC: ['363', '307', '323']
#
# Best Match FSC: ['560']
# Row FSC: ['525']
#
# Best Match FSC: ['128', '604']
# Row FSC: ['131', 'D27']
#
# Best Match FSC: ['313', '106', '252']
# Row FSC: ['523', '524', '428', '252', '376', '250']
#
# Best Match FSC: ['71', '544']
# Row FSC: ['71']
#
# Best Match FSC: ['296', '16', '292']
# Row FSC: ['439', '248']
#
# Best Match FSC: ['530', '514', '435']
# Row FSC: ['424', '514']
#
# Best Match FSC: ['360', '369']
# Row FSC: ['227', '173']
#
# Best Match FSC: ['128']
# Row FSC: ['128']
#
# Best Match FSC: ['239']
# Row FSC: ['92', '91', '251', '137']
#
# Best Match FSC: ['156', '427', '204', '118', '437']
# Row FSC: ['65']
#
# Best Match FSC: ['348']
# Row FSC: ['370', '340']
#
# Best Match FSC: ['370', '375', '379', '307', '328']
# Row FSC: ['340', '324', '320']
#
# Best Match FSC: ['285']
# Row FSC: ['24']
#
# Best Match FSC: ['399', '347']
# Row FSC: ['2']
#
# Best Match FSC: ['34']
# Row FSC: ['164']
#
# Best Match FSC: ['123']
# Row FSC: ['222', '141']
#
# Best Match FSC: ['204']
# Row FSC: ['430']
#
# Best Match FSC: ['361', '357']
# Row FSC: ['428', '244', '432', '75', '228']
#
# Best Match FSC: ['219', '337']
# Row FSC: ['206', '220']
#
# Best Match FSC: ['360', '386', '369', '358', '345']
# Row FSC: ['364']
#
# Best Match FSC: ['356', '359', '250']
# Row FSC: ['378', '250']
#
# Best Match FSC: ['359', '385']
# Row FSC: ['257']
#
# Best Match FSC: ['219', '34', '137', '251']
# Row FSC: ['360', '242']
#
# Best Match FSC: ['273']
# Row FSC: ['415', '384']
#
# Best Match FSC: ['208']
# Row FSC: ['208', '196']
#
# Best Match FSC: ['323', '363', '322']
# Row FSC: ['363', '323']
#
# Best Match FSC: ['423']
# Row FSC: ['378']
#
# Best Match FSC: ['118', '414', '204', '156']
# Row FSC: ['134', '414']
#
# Best Match FSC: ['623']
# Row FSC: ['606']
#
# Best Match FSC: ['435', '422', '73', '414', '198', '53']
# Row FSC: ['405', '254']
#
# Best Match FSC: ['361', '307']
# Row FSC: ['454', '119', '160', '236']
#
# Best Match FSC: ['434']
# Row FSC: ['381', '395']
#
# Best Match FSC: ['368', '200', '219']
# Row FSC: ['604']
#
# Best Match FSC: ['73']
# Row FSC: ['369', '360']
#
# Best Match FSC: ['260', '204']
# Row FSC: ['264']
#
# Best Match FSC: ['72', '192', '29']
# Row FSC: ['310', '318']
#
# Best Match FSC: ['435', '424', '436']
# Row FSC: ['228', '436']
#
# Best Match FSC: ['55', '15', '181']
# Row FSC: ['261']
#
# Best Match FSC: ['424', '435', '514', '530', '536']
# Row FSC: ['435', '536']
#
# Best Match FSC: ['55', '202', '210', '196']
# Row FSC: ['55', '60']
#
# Best Match FSC: ['166']
# Row FSC: ['242', '280', '297']
#
# Best Match FSC: ['356']
# Row FSC: ['250']
#
# Best Match FSC: ['437']
# Row FSC: ['438']
#
# Best Match FSC: ['36']
# Row FSC: ['53', '242']
#
# Best Match FSC: ['446', '40', '84']
# Row FSC: ['446', '273']
#
# Best Match FSC: ['66', '15']
# Row FSC: ['92', '74']
#
# Best Match FSC: ['250', '356']
# Row FSC: ['345']
#
# Best Match FSC: ['424']
# Row FSC: ['426', '260', '424', '435']
#
# Best Match FSC: ['74', '192']
# Row FSC: ['74', '242', '360']
#
# Best Match FSC: ['604']
# Row FSC: ['604']
#
# Best Match FSC: ['438', '148', '117']
# Row FSC: ['228', '219']
#
# Best Match FSC: ['528', '260']
# Row FSC: ['528', '428']
#
# Best Match FSC: ['365', '257']
# Row FSC: ['438']
#
# Best Match FSC: ['414']
# Row FSC: ['188', '294']
#
# Best Match FSC: ['524', '526']
# Row FSC: ['162']
#
# Best Match FSC: ['206', '383']
# Row FSC: ['4']
#
# Best Match FSC: ['365']
# Row FSC: ['395', '381', '84']
#
# Best Match FSC: ['51', '269', '165', '408', '409', '83']
# Row FSC: ['418', '60', '417', '290']
#
# Best Match FSC: ['526']
# Row FSC: ['544']
#
# Best Match FSC: ['435', '536']
# Row FSC: ['435']
#
# Best Match FSC: ['345', '386', '709', '348', '707']
# Row FSC: ['358', '360']
#
# Best Match FSC: ['248', '297', '403']
# Row FSC: ['248', '411']
#
# Best Match FSC: ['179', '364']
# Row FSC: ['482', '128']
#
# Best Match FSC: ['325', '329']
# Row FSC: ['381']
#
# Best Match FSC: ['360']
# Row FSC: ['382', '348', '356', '250', '53', '162', '493', '206', '242']
#
# Best Match FSC: ['PLT']
# Row FSC: ['Plt']
#
# Best Match FSC: ['405', '404', '472', '473']
# Row FSC: ['473']
#
# Best Match FSC: ['438', '257']
# Row FSC: ['438']
#
# Best Match FSC: ['188']
# Row FSC: ['188', '187', '192', '74', '182', '185', '254']
#
# Best Match FSC: ['525']
# Row FSC: ['544']
#
# Best Match FSC: ['89']
# Row FSC: ['250']
#
# Best Match FSC: ['203', '570']
# Row FSC: ['526', '250']
#
# Best Match FSC: ['433', '174', '156']
# Row FSC: ['105', '49', '296', '114', '220', '52']
#
# Best Match FSC: ['211', '206']
# Row FSC: ['312', '108', '220']
#
# Best Match FSC: ['369']
# Row FSC: ['271']
#
# Best Match FSC: ['204', '427']
# Row FSC: ['350', '358']
#
# Best Match FSC: ['361', '29']
# Row FSC: ['Plt']
#
# Best Match FSC: ['395', '716']
# Row FSC: ['380', '360', '340', '395']
#
# Best Match FSC: ['435', '424', '436']
# Row FSC: ['435', '424']
#
# Best Match FSC: ['426']
# Row FSC: ['128']
#
# Best Match FSC: ['526']
# Row FSC: ['252', '260', '430']
#
# Best Match FSC: ['606', '602']
# Row FSC: ['206', '428']
#
# Best Match FSC: ['73']
# Row FSC: ['249']
#
# Best Match FSC: ['257']
# Row FSC: ['349']
#
# Best Match FSC: ['380']
# Row FSC: ['343']
#
# Best Match FSC: ['340', '174', '361']
# Row FSC: ['361', '219', '315']
#
# Best Match FSC: ['109', '312']
# Row FSC: ['312']
#
# Best Match FSC: ['455', '370']
# Row FSC: ['379', '455']
#
# Best Match FSC: ['385']
# Row FSC: ['220']
#
# Best Match FSC: ['73', '364', '123']
# Row FSC: ['68']
#
# Best Match FSC: ['297']
# Row FSC: ['297', '296']
#
# Best Match FSC: ['361']
# Row FSC: ['361', '323', '363', '364']
#
# Best Match FSC: ['395', '340', '370', '345']
# Row FSC: ['714']
#
# Best Match FSC: ['527', '524']
# Row FSC: ['510', '252']
#
# Best Match FSC: ['429', '220']
# Row FSC: ['361', '381']
#
# Best Match FSC: ['210', '156', '264', '428']
# Row FSC: ['5', '446', '482']
#
# Best Match FSC: ['313', '428']
# Row FSC: ['250']
#
# Best Match FSC: ['280', '200']
# Row FSC: ['180', '280']
#
# Best Match FSC: ['117', '427', '260', '424', '428']
# Row FSC: ['521']
#
# Best Match FSC: ['438']
# Row FSC: ['257']
#
# Best Match FSC: ['436', '435', '424', '935']
# Row FSC: ['433', '600', '33']
#
# Best Match FSC: ['409', '29', '83']
# Row FSC: ['156', '425', '81', '152', '264', '249']
#
# Best Match FSC: ['455', '370', '340']
# Row FSC: ['379', '455', '340', '380', '395', '235']
#
# Best Match FSC: ['544', '546', '514']
# Row FSC: ['514']
#
# Best Match FSC: ['5', '267', '53', '112', '29']
# Row FSC: ['156', '264', '19', '53']
#
# Best Match FSC: ['431', '137']
# Row FSC: ['60']
#
# Best Match FSC: ['60', '239']
# Row FSC: ['123']
#
# Best Match FSC: ['224']
# Row FSC: ['16', '292']
#
# Best Match FSC: ['504', '544']
# Row FSC: ['435', '536', '800']
#
# Best Match FSC: ['528']
# ...
# Row FSC: ['428', '204']
#
# Best Match FSC: ['514', '424']
# Row FSC: ['435']
#
# Best Match FSC: ['358']
# Row FSC: ['323', '363', '55']
#
# Best Match FSC: ['437', '257']
# Row FSC: ['72']
#
# Best Match FSC: ['224']
# Row FSC: ['29', '416', '446', 'D12']
#
# Best Match FSC: ['522', '430', '359']
# Row FSC: ['257']
#
# Best Match FSC: ['81']
# Row FSC: ['141']
#
# Best Match FSC: ['210']
# Row FSC: ['523', '524', '252', '264', '3']
#
# Best Match FSC: ['204']
# Row FSC: ['514']
#
# Best Match FSC: ['435', '935']
# Row FSC: ['435']
#
# Best Match FSC: ['123', '336']
# Row FSC: ['219', '362']
#
# Best Match FSC: ['119']
# Row FSC: ['423', '210']
#
# Best Match FSC: ['424', '514']
# Row FSC: ['428', '138', '426', '264']
#
# Best Match FSC: ['123']
# Row FSC: ['323', '455']
#
# Best Match FSC: ['435', '935', '536', '424']
# Row FSC: ['365']
#
# Best Match FSC: ['244', '114', '441', '297']
# Row FSC: ['99', '126', '426', 'D 7']
#
# Best Match FSC: ['204']
# Row FSC: ['585']
#
# Best Match FSC: ['4', '211', '248', '312', '16', '74']
# Row FSC: ['606']
#
# Best Match FSC: ['435']
# Row FSC: ['502']
#
# Best Match FSC: ['239']
# Row FSC: ['417']
#
# Best Match FSC: ['375', '370', '371', '379']
# Row FSC: ['340', '370', '375']
#
# Best Match FSC: ['128', '73']
# Row FSC: ['353']
#
# Best Match FSC: ['260']
# Row FSC: ['548', '560', '562', '568']
#
# Best Match FSC: ['358', '360', '348', '386']
# Row FSC: ['360']
#
# Best Match FSC: ['717']
# Row FSC: ['395', '711']
#
# Best Match FSC: ['376']
# Row FSC: ['604', '239']
#
# Best Match FSC: ['62']
# Row FSC: ['62', '198']
#
# Best Match FSC: ['202', '203', '159']
# Row FSC: ['106']
#
# Best Match FSC: ['66', '15']
# Row FSC: ['248', '211', '224']
#
# Best Match FSC: ['378', '324', '128']
# Row FSC: ['354']
#
# Best Match FSC: ['206', '211']
# Row FSC: ['273']
#
# Best Match FSC: ['266', '75']
# Row FSC: ['87', '289']
#
# Best Match FSC: ['206', '606']
# Row FSC: ['223', 'D 6']
#
# Best Match FSC: ['380']
# Row FSC: ['235', '209']
#
# Best Match FSC: ['446', '403', '411']
# Row FSC: ['242', '206', '220', '225', '352']
#
# Best Match FSC: ['72', '29']
# Row FSC: ['528', '525', '556']
#
# Best Match FSC: ['414']
# Row FSC: ['165']
#
# Best Match FSC: ['430']
# Row FSC: ['428', '524', '525', '492', '355']
#
# Best Match FSC: ['324', '323', '330', '307', '328']
# Row FSC: ['363', '323', '307', '310', '318', '333', '379', '722']
#
# Best Match FSC: ['354', '250']
# Row FSC: ['324']
#
# Best Match FSC: ['357']
# Row FSC: ['438']
#
# Best Match FSC: ['713', '707', '709', '710', '380']
# Row FSC: ['395']
#
# Best Match FSC: ['27', '220', '217', '292']
# Row FSC: ['198', '209']
#
# Best Match FSC: ['424']
# Row FSC: ['426']
#
# Best Match FSC: ['424', '206', '530', '534']
# Row FSC: ['623', '606']
#
# Best Match FSC: ['250', '357', '29']
# Row FSC: ['174', '336', '264', '335']
#
# Best Match FSC: ['358', '357', '307', '328']
# Row FSC: ['330', '323']
#
# Best Match FSC: ['330']
# Row FSC: ['324', '331', '455', '343']
#
# Best Match FSC: ['707', '709', '395', '379', '345']
# Row FSC: ['364', '395', '707']
#
# Best Match FSC: ['525', '428']
# Row FSC: ['525']
#
# Best Match FSC: ['297', '108', '248']
# Row FSC: ['74', '901', '403', '464', '409']
#
# Best Match FSC: ['475', '477']
# Row FSC: ['74', '474', '192']
#
# Best Match FSC: ['414', '241', '83']
# Row FSC: ['473']
#
# Best Match FSC: ['123']
# Row FSC: ['235', '415', '60', '340', '290', '444']
#
# Best Match FSC: ['424', '549', '560', '260']
# Row FSC: ['260', '435']
#
# Best Match FSC: ['267', '280']
# Row FSC: ['296', '293']
#
# Best Match FSC: ['149', '264']
# Row FSC: ['204']
#
# Best Match FSC: ['455', '379']
# Row FSC: ['455', '370', '379']
#
# Best Match FSC: ['280', '135']
# Row FSC: ['124', '446']
#
# Best Match FSC: ['339']
# Row FSC: ['257']
#
# Best Match FSC: ['114', '405']
# Row FSC: ['244', '114']
#
# Best Match FSC: ['104', '105', '414', '198', '37']
# Row FSC: ['414', '198']
#
# Best Match FSC: ['430', '428', '106']
# Row FSC: ['361']
#
# Best Match FSC: ['430']
# Row FSC: ['528', '524', '525']
#
# Best Match FSC: ['359', '347', '250', '358']
# Row FSC: ['359']
#
# Best Match FSC: ['371', '395', '326', '364', '365']
# Row FSC: ['400', '101']
#
# Best Match FSC: ['340']
# Row FSC: ['375', '334', '331', '332', '333']
#
# Best Match FSC: ['192', '74', '180', '464']
# Row FSC: ['251', '137', '98']
#
# Best Match FSC: ['166']
# Row FSC: ['166']
#
# Best Match FSC: ['435']
# Row FSC: ['536', '435']
#
# Best Match FSC: ['128', '604']
# Row FSC: ['604', '210', '128']
#
# Best Match FSC: ['156', '437', '438']
# Row FSC: ['430', '346', '365', '369']
#
# Best Match FSC: ['56', '302']
# Row FSC: ['156', '65', '118', '198', '214', '193', '134']
#
# Best Match FSC: ['250', '357', '358']
# Row FSC: ['455', '370']
#
# Best Match FSC: ['606', '600', '128']
# Row FSC: ['53', '29', '140']
#
# Best Match FSC: ['162', '428']
# Row FSC: ['536', '562']
#
# Best Match FSC: ['61', '175']
# Row FSC: ['219', '204']
#
# Best Match FSC: ['174', '339']
# Row FSC: ['29', '264', '336', '439', '174']
#
# Best Match FSC: ['257', '29', '174', '156', '438', '361']
# Row FSC: ['29', '174', '361']
#
# Best Match FSC: ['192', '74']
# Row FSC: ['139', '254']
#
# Best Match FSC: ['180']
# Row FSC: ['280', '180']
#
# Best Match FSC: ['540', '514']
# Row FSC: ['424', '264', '514']
#
# Best Match FSC: ['333', '455', '370', '340']
# Row FSC: ['455']
#
# Best Match FSC: ['707']
# Row FSC: ['395', '358', '364', '382', '707']
#
# Best Match FSC: ['192', '74', '64']
# Row FSC: ['200', '308', '123']
#
# Best Match FSC: ['30', '132']
# Row FSC: ['428', '411', '257']
#
# Best Match FSC: ['220']
# Row FSC: ['337', '29']
#
# Best Match FSC: ['326', '327']
# Row FSC: ['361', '323', '307', '320', '357']
#
# Best Match FSC: ['370', '340']
# Row FSC: ['307']
#
# Best Match FSC: ['514', '548']
# Row FSC: ['548', '514']
#
# Best Match FSC: ['198', '53', '177', '214']
# Row FSC: ['156', '198']
#
# Best Match FSC: ['524', '428', '427', '264']
# Row FSC: ['260']
#
# Best Match FSC: ['514', '546', '552', '564', '544', '549']
# Row FSC: ['552']
#
# Best Match FSC: ['524']
# Row FSC: ['510']
#
# Best Match FSC: ['564', '546', '548']
# Row FSC: ['568']
#
# Best Match FSC: ['324']
# Row FSC: ['332', '325', '333']
#
# Best Match FSC: ['493', '226']
# Row FSC: ['101', '83', '226', '400']
#
# Best Match FSC: ['250', '356']
# Row FSC: ['382', '364', '358', '356']
#
# Best Match FSC: ['60', '204', '73']
# Row FSC: ['315', '323', '363', '340', '362']
#
# Best Match FSC: ['453', '53', '414', '198']
# Row FSC: ['355', '271', '354']
#
# Best Match FSC: ['56', '248']
# Row FSC: ['108', '211', '49', '292', '280']
#
# Best Match FSC: ['187', '414', '182']
# Row FSC: ['53']
#
# Best Match FSC: ['293', '213']
# Row FSC: ['29', '198', '254', '383', '414']
#
# Best Match FSC: ['277', '49', '254', '156']
# Row FSC: ['156', '138', '29']
#
# Best Match FSC: ['269', '279']
# Row FSC: ['425', '264']
#
# Best Match FSC: ['356', '250', '348', '358', '378', '382']
# Row FSC: ['132', '606', '128', '347']
#
# Best Match FSC: ['530']
# Row FSC: ['119']
#
# Best Match FSC: ['600', '128', '382']
# Row FSC: ['250']
#
# Best Match FSC: ['336']
# Row FSC: ['438']
#
# Best Match FSC: ['707', '709', '395', '379', '345']
# Row FSC: ['395', '711']
#
# Best Match FSC: ['38', '219']
# Row FSC: ['219']
#
# Best Match FSC: ['348', '250']
# Row FSC: ['382', '358', '250']
#
# Best Match FSC: ['526', '524']
# Row FSC: ['604']
#
# Best Match FSC: ['544', '514']
# Row FSC: ['260', '424']
#
# Best Match FSC: ['285']
# Row FSC: ['2']
#
# Best Match FSC: ['355', '219', '198']
# Row FSC: ['219', '337', '200']
#
# Best Match FSC: ['424', '524']
# Row FSC: ['528']
#
# Best Match FSC: ['297']
# Row FSC: ['280', '296', '297']
#
# Best Match FSC: ['359', '385']
# Row FSC: ['359', '345', '348']
#
# Best Match FSC: ['424', '428']
# Row FSC: ['514', '424', '516', '512']
#
# Best Match FSC: ['528', '428']
# Row FSC: ['427']
#
# Best Match FSC: ['200', '310', '333', '73']
# Row FSC: ['257']
#
# Best Match FSC: ['343', '364', '455']
# Row FSC: ['372', '428', '356']
#
# Best Match FSC: ['260', '428']
# Row FSC: ['525', '524', '528']
#
# Best Match FSC: ['901', '239', '427', '118']
# Row FSC: ['239', '261', '4']
#
# Best Match FSC: ['360', '371']
# Row FSC: ['358']
#
# Best Match FSC: ['208', '502']
# Row FSC: ['423', '252', '422', '106', '34']
#
# Best Match FSC: ['428', '156', '139', '162', '34']
# Row FSC: ['29', '241']
#
# Best Match FSC: ['219', '427']
# Row FSC: ['219', '29', '425', '222']
#
# Best Match FSC: ['114', '405']
# Row FSC: ['65', '425', '264']
#
# Best Match FSC: ['260']
# Row FSC: ['528', '521']
#
# Best Match FSC: ['228', '219']
# Row FSC: ['430']
#
# Best Match FSC: ['178', '340']
# Row FSC: ['307', '323', '361', '364']
#
# Best Match FSC: ['283', '402', '428']
# Row FSC: ['53']
#
# Best Match FSC: ['408', '76']
# Row FSC: ['408', '409', '407']
#
# Best Match FSC: ['148', '204', '427']
# Row FSC: ['549']
#
# Best Match FSC: ['427', '423', '118']
# Row FSC: ['204', '427']
#
# Best Match FSC: ['117', '264']
# Row FSC: ['427', '156', '428', '204']
#
# Best Match FSC: ['250', '315', '313']
# Row FSC: ['350', '174']
#
# Best Match FSC: ['338', '73', '252', '29']
# Row FSC: ['338', '361']
#
# Best Match FSC: ['15']
# Row FSC: ['406', '239', '15']
#
# Best Match FSC: ['204', '118', '156', '269', '335']
# Row FSC: ['373']
#
# Best Match FSC: ['116', '273', '46']
# Row FSC: ['181', '128']
#
# Best Match FSC: ['177', '251']
# Row FSC: ['347']
#
# Best Match FSC: ['606', '623']
# Row FSC: ['376', '73']
#
# Best Match FSC: ['310', '318']
# Row FSC: ['310', '417', '318']
#
# Best Match FSC: ['600', '128']
# Row FSC: ['705', '364']
#
# Best Match FSC: ['423']
# Row FSC: ['293']
#
# Best Match FSC: ['380']
# Row FSC: ['709', '713']
#
# Best Match FSC: ['33', '248']
# Row FSC: ['76']
#
# Best Match FSC: ['36']
# Row FSC: ['318', '364', '395', '434', '340']
#
# Best Match FSC: ['530', '435']
# Row FSC: ['252', '208', '385']
#
# Best Match FSC: ['310']
# Row FSC: ['180', '192']
#
# Best Match FSC: ['203', '202', '435', '44', '568']
# Row FSC: ['165', '62', '318']
#
# Best Match FSC: ['166', '277']
# Row FSC: ['405', '91', '248']
#
# Best Match FSC: ['363', '323', '333']
# Row FSC: ['260', '568']
#
# Best Match FSC: ['52']
# Row FSC: ['52', '256']
#
# Best Match FSC: ['148', '252']
# Row FSC: ['430', '346']
#
# Best Match FSC: ['428', '264']
# Row FSC: ['525']
#
# Best Match FSC: ['235', '902']
# Row FSC: ['714']
#
# Best Match FSC: ['52', '182', '248', '254']
# Row FSC: ['223', '28', '428']
#
# Best Match FSC: ['455', '379']
# Row FSC: ['358', '455', '370', '375', '332']
#
# Best Match FSC: ['426']
# Row FSC: ['424', '514', '132']
#
# Best Match FSC: ['229', '206']
# Row FSC: ['223', '211']
#
# Best Match FSC: ['43', '220', '441', '134']
# Row FSC: ['439']
#
# Best Match FSC: ['220']
# Row FSC: ['182', '4']
#
# Best Match FSC: ['335']
# Row FSC: ['204']
#
# Best Match FSC: ['318', '236', '126', '98']
# Row FSC: ['318', '123', '251']
#
# Best Match FSC: ['435', '514', '536']
# Row FSC: ['358']
#
# Best Match FSC: ['375']
# Row FSC: ['358', '381', '455', '348']
#
# Best Match FSC: ['426', '435']
# Row FSC: ['426', '435']
#
# Best Match FSC: ['210', '242', '55', '57']
# Row FSC: ['419']
#
# Best Match FSC: ['101', '70', '292', '335', '118', '403']
# Row FSC: ['72', '29', '51', '425']
#
# Best Match FSC: ['514', '530']
# Row FSC: ['546', '514']
#
# Best Match FSC: ['184', '220', '215', '206', '141']
# Row FSC: ['72', '29', '211']
#
# Best Match FSC: ['399', '430']
# Row FSC: ['74', '156', '252']
#
# Best Match FSC: ['126', '422', '210']
# Row FSC: ['261', '55', '123']
#
# Best Match FSC: ['426']
# Row FSC: ['426']
#
# Best Match FSC: ['423']
# Row FSC: ['60', '149']
#
# Best Match FSC: ['371', '395', '714', '360', '365']
# Row FSC: ['307', '340', '380', '365']
#
# Best Match FSC: ['192']
# Row FSC: ['417', '92', '303']
#
# Best Match FSC: ['429']
# Row FSC: ['428', '426']
#
# Best Match FSC: ['707', '395', '1']
# Row FSC: ['700', '438']
#
# Best Match FSC: ['122', '165']
# Row FSC: ['119']
#
# Best Match FSC: ['324']
# Row FSC: ['73']
#
# Best Match FSC: ['180']
# Row FSC: ['318']
#
# Best Match FSC: ['423']
# Row FSC: ['530', '210']
#
# Best Match FSC: ['106', '523', '101', '534', '552', '549', '546', '540', '544', '548', '428', '427', '524']
# Row FSC: ['502']
#
# Best Match FSC: ['346', '101', '400']
# Row FSC: ['310', '29', '148', '427', '204', '174']
#
# Best Match FSC: ['356', '359', '250']
# Row FSC: ['372']
#
# Best Match FSC: ['250', '257', '358']
# Row FSC: ['358', '361']
#
# Best Match FSC: ['91', '60']
# Row FSC: ['91', '92']
#
# Best Match FSC: ['235', '359', '250']
# Row FSC: ['73', '128']
#
# Best Match FSC: ['384']
# Row FSC: ['524']
#
# Best Match FSC: ['320']
# Row FSC: ['315']
#
# Best Match FSC: ['526']
# Row FSC: ['525', '523', '524']
#
# Best Match FSC: ['219', '347', '359']
# Row FSC: ['128', '351']
#
# Best Match FSC: ['74']
# Row FSC: ['318']
#
# Best Match FSC: ['359']
# Row FSC: ['418', '428']
#
# Best Match FSC: ['528', '428']
# Row FSC: ['219']
#
# Best Match FSC: ['250', '354', '318']
# Row FSC: ['128']
#
# Best Match FSC: ['333', '307']
# Row FSC: ['372']
#
# Best Match FSC: ['455', '375', '331']
# Row FSC: ['318', '328', '329', '340']
#
# Best Match FSC: ['435']
# Row FSC: ['435']
#
# Best Match FSC: ['320']
# Row FSC: ['408', '409', '33', '340']
#
# Best Match FSC: ['29', '269', '606']
# Row FSC: ['156']
#
# Best Match FSC: ['360']
# Row FSC: ['606', '600', '623']
#
# Best Match FSC: ['359']
# Row FSC: ['428', '430', '346']
#
# Best Match FSC: ['604']
# Row FSC: ['294', '15', '248', '141', '383']
#
# Best Match FSC: ['229', '206']
# Row FSC: ['215', '220']
#
# Best Match FSC: ['424']
# Row FSC: ['524', '525', '526', '528']
#
# Best Match FSC: ['260', '546']
# Row FSC: ['548', '71', '546', '544']
#
# Best Match FSC: ['514', '548']
# Row FSC: ['128', '606']
#
# Best Match FSC: ['280']
# Row FSC: ['280', '220']
#
# Best Match FSC: ['252', '568']
# Row FSC: ['252', '106']
#
# Best Match FSC: ['345']
# Row FSC: ['360', '358']
#
# Best Match FSC: ['228', '148']
# Row FSC: ['228', '252', '29']
#
# Best Match FSC: ['377', '364']
# Row FSC: ['375', '370']
#
# Best Match FSC: ['166']
# Row FSC: ['188', '192']
#
# Best Match FSC: ['407', '408']
# Row FSC: ['242', '400']
#
# Best Match FSC: ['548', '514']
# Row FSC: ['71', '260']
#
# Best Match FSC: ['716']
# Row FSC: ['437']
#
# Best Match FSC: ['455', '327']
# Row FSC: ['331', '73']
#
# Best Match FSC: ['365']
# Row FSC: ['370']
#
# Best Match FSC: ['257', '438']
# Row FSC: ['206', '174', '361', '357', '29']
#
# Best Match FSC: ['366', '601']
# Row FSC: ['237', '60']
#
# Best Match FSC: ['370', '455', '375']
# Row FSC: ['359']
#
# Best Match FSC: ['549']
# Row FSC: ['380', '455']
#
# Best Match FSC: ['396']
# Row FSC: ['395', '434']
#
# Best Match FSC: ['204']
# Row FSC: ['204', '128']
#
# Best Match FSC: ['365']
# Row FSC: ['324', '307', '327']
#
# Best Match FSC: ['215']
# Row FSC: ['141', '221']
#
# Best Match FSC: ['252', '260']
# Row FSC: ['260']
#
# Best Match FSC: ['209', '210']
# Row FSC: ['266', '501']
#
# Best Match FSC: ['425', '264']
# Row FSC: ['210', '96']
#
# Best Match FSC: ['528', '260']
# Row FSC: ['525', '524']
#
# Best Match FSC: ['307', '257']
# Row FSC: ['257', '307']
#
# Best Match FSC: ['530', '536', '435', '424']
# Row FSC: ['435', '436', '536', '935']
#
# Best Match FSC: ['335', '324', '128']
# Row FSC: ['324']
#
# Best Match FSC: ['29', '72', '53', '156']
# Row FSC: ['271']
#
# Best Match FSC: ['424']
# Row FSC: ['264', '36']
#
# Best Match FSC: ['364']
# Row FSC: ['370', '365', '395']
#
# Best Match FSC: ['435', '422']
# Row FSC: ['219', '126', '165', '190', '62']
#
# Best Match FSC: ['139']
# Row FSC: ['83']
#
# Best Match FSC: ['524']
# Row FSC: ['522', '528', '385']
#
# Best Match FSC: ['118', '427']
# Row FSC: ['524', '103']
#
# Best Match FSC: ['415']
# Row FSC: ['372']
#
# Best Match FSC: ['177', '251']
# Row FSC: ['137']
#
# Best Match FSC: ['333', '29']
# Row FSC: ['264']
#
# Best Match FSC: ['326', '327']
# Row FSC: ['310']
#
# Best Match FSC: ['74', '251']
# Row FSC: ['23', '254', '156']
#
# Best Match FSC: ['358', '360']
# Row FSC: ['348']
#
# Best Match FSC: ['527', '524']
# Row FSC: ['430']
#
# Best Match FSC: ['242', '156']
# Row FSC: ['100', '72']
#
# Best Match FSC: ['604', '128', '33', '600']
# Row FSC: ['73']
#
# Best Match FSC: ['180', '280']
# Row FSC: ['318', '364']
#
# Best Match FSC: ['188', '267']
# Row FSC: ['192', '60', '137', '91', '477']
#
# Best Match FSC: ['428', '442']
# Row FSC: ['204', '437']
#
# Best Match FSC: ['273', '434']
# Row FSC: ['382', '358', '356', '250', '209']
#
# Best Match FSC: ['530', '514', '930']
# Row FSC: ['514', '536', '549']
#
# Best Match FSC: ['451']
# Row FSC: ['376', '294', '403', '292', '254', '92']
#
# Best Match FSC: ['554', '568', '566']
# Row FSC: ['562']
#
# Best Match FSC: ['493', '226']
# Row FSC: ['209']
#
# Best Match FSC: ['707', '395', '1']
# Row FSC: ['198', '271']
#
# Best Match FSC: ['52', '277', '428']
# Row FSC: ['174', '361']
#
# Best Match FSC: ['29', '269', '606']
# Row FSC: ['73']
#
# Best Match FSC: ['239', '251']
# Row FSC: ['220', '215', '222']
#
# Best Match FSC: ['228', '438']
# Row FSC: ['437', '257', '438']

# %% [markdown]
# ## Calculate Precision and Recall
#
# Precision = (n of recommended items that are relevant) / (n of recommended items )
#
# Recall = (n of recommended items that are relevant) / (total n of relevant items)

# %%
train_classes_data

# For an item to be considered relevant needs to have at least 50% of classes similar to the input's classes 
def getNumberOfRelevantItems(recommendedClasses, inputClasses):
  
  if pd.Series(recommendedClasses).isin(inputClasses).any():
    print("Contem!")
    print(recommendedClasses)
    print(inputClasses)
    print("\n")
  

def evaluate_classes():
  for index,row in test_data.iterrows():
    test_Data_sample = get_model_best_match(row['Resumo'])
    match_ID = str(modelIndexToDataframeIndex[test_Data_sample[0][0]-1])

    best_match_data = train_data[train_data['ID'] == match_ID]
    
    best_match_fsc_row = get_FSC_classes_row(match_ID)
    test_fsc_row = get_FSC_classes_row(row['ID'])
  
    fsc_list_best_match = validate_parse_fsc(best_match_fsc_row)
    fsc_test_data_row = validate_parse_fsc(test_fsc_row)

    #print("Best Match FSC: " + str(fsc_list_best_match))
    #print("Row FSC: " + str(fsc_test_data_row) + "\n")

    recommended_classes_array = np.array(fsc_list_best_match)
    input_classes_array = np.array(fsc_test_data_row)
    getNumberOfRelevantItems(recommended_classes_array,input_classes_array)

evaluate_classes()


def getPrecision():


  return 


def getRecall():

  return
# Out:
# Contem!
# ['8' '428' '503']
# ['96' '428']
#
#
# Contem!
# ['362' '40' '52' '431' '206']
# ['220' '206']
#
#
# Contem!
# ['530']
# ['530']
#
#
# Contem!
# ['180' '317' '123']
# ['244' '62' '165' '123' '60']
#
#
# Contem!
# ['424']
# ['424' '514']
#
#
# Contem!
# ['364' '371']
# ['364' '318' '425' '264' '29']
#
#
# Contem!
# ['514']
# ['424' '514']
#
#
# Contem!
# ['540' '544' '546' '549' '514']
# ['548' '514']
#
#
# Contem!
# ['Plt']
# ['Plt']
#
#
# Contem!
# ['375' '371' '370' '455' '324']
# ['455' '334']
#
#
# Contem!
# ['250' '257']
# ['422' '73' '250' '324']
#
#
# Contem!
# ['206' '220']
# ['206' '116' '246' '40']
#
#
# Contem!
# ['74' '192']
# ['192']
#
#
# Contem!
# ['430' '369' '359' '428']
# ['430' '358']
#
#
# Contem!
# ['365' '371']
# ['365']
#
#
# Contem!
# ['315']
# ['315' '327' '363']
#
#
# Contem!
# ['435' '530']
# ['435' '536']
#
#
# Contem!
# ['424' '514']
# ['514' '435' '536' '935']
#
#
# Contem!
# ['29' '174' '437' '264' '257']
# ['257' '437' '365' '438']
#
#
# Contem!
# ['439' '385']
# ['439']
#
#
# Contem!
# ['428' '347']
# ['428' '525']
#
#
# Contem!
# ['430' '525' '526']
# ['96' '204' '427' '526' '264']
#
#
# Contem!
# ['455' '340' '434']
# ['455' '704' '370']
#
#
# Contem!
# ['371' '395' '370']
# ['370' '395']
#
#
# Contem!
# ['355' '361']
# ['96' '118' '356' '355']
#
#
# Contem!
# ['424' '530' '435']
# ['435' '436']
#
#
# Contem!
# ['438']
# ['438']
#
#
# Contem!
# ['260']
# ['260' '526']
#
#
# Contem!
# ['206' '220']
# ['206']
#
#
# Contem!
# ['348' '345' '455' '364' '395' '709']
# ['380' '709' '713']
#
#
# Contem!
# ['364' '179' '375' '455']
# ['364']
#
#
# Contem!
# ['604']
# ['604']
#
#
# Contem!
# ['350' '455']
# ['381' '455']
#
#
# Contem!
# ['428' '427' '229' '527' '524']
# ['528' '524' '525']
#
#
# Contem!
# ['24']
# ['248' '24' '40' '428' '211' '281']
#
#
# Contem!
# ['267' '280']
# ['280' '180' '364']
#
#
# Contem!
# ['536' '435' '800']
# ['435' '530']
#
#
# Contem!
# ['365']
# ['365' '357']
#
#
# Contem!
# ['436' '422' '4' '358' '52' '424' '128']
# ['137' '52']
#
#
# Contem!
# ['346' '350' '250']
# ['346' '356']
#
#
# Contem!
# ['435' '530']
# ['536' '435']
#
#
# Contem!
# ['429']
# ['429']
#
#
# Contem!
# ['429' '252']
# ['29' '429']
#
#
# Contem!
# ['362']
# ['362']
#
#
# Contem!
# ['536' '435' '514']
# ['435' '536']
#
#
# Contem!
# ['324' '439']
# ['439']
#
#
# Contem!
# ['208']
# ['159' '202' '203' '196' '208' '110']
#
#
# Contem!
# ['210' '422' '222' '137' '239']
# ['210']
#
#
# Contem!
# ['514' '424']
# ['424']
#
#
# Contem!
# ['340' '370' '179' '371']
# ['370']
#
#
# Contem!
# ['364' '29']
# ['364' '239' '47' '118']
#
#
# Contem!
# ['514']
# ['424' '514']
#
#
# Contem!
# ['75' '148']
# ['148']
#
#
# Contem!
# ['280' '297']
# ['180' '280' '340' '24']
#
#
# Contem!
# ['711' '365']
# ['365']
#
#
# Contem!
# ['564' '424' '514']
# ['424']
#
#
# Contem!
# ['60' '204' '73']
# ['422' '204' '60' '123']
#
#
# Contem!
# ['426' '424']
# ['264' '424' '436']
#
#
# Contem!
# ['514']
# ['514']
#
#
# Contem!
# ['430' '528' '522']
# ['430']
#
#
# Contem!
# ['330' '363' '323']
# ['323' '363']
#
#
# Contem!
# ['430' '522']
# ['430']
#
#
# Contem!
# ['446' '112' '428' '156']
# ['446' '29']
#
#
# Contem!
# ['602' '604']
# ['2' '128' '602']
#
#
# Contem!
# ['379']
# ['379']
#
#
# Contem!
# ['356' '250']
# ['250' '317' '321' '323']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-92d0170f2890> in <module>()
#      31     getNumberOfRelevantItems(recommended_classes_array,input_classes_array)
#      32
# ---> 33 evaluate_classes()
#      34
#      35
#
# <ipython-input-33-92d0170f2890> in evaluate_classes()
#      13 def evaluate_classes():
#      14   for index,row in test_data.iterrows():
# ---> 15     test_Data_sample = get_model_best_match(row['Resumo'])
#      16     match_ID = str(modelIndexToDataframeIndex[test_Data_sample[0][0]-1])
#      17
#
# <ipython-input-25-8c3f57f5f137> in get_model_best_match(abstract)
#       1 def get_model_best_match(abstract):
# ----> 2   inferred_vector = model.infer_vector(gensim.utils.simple_preprocess(abstract))
#       3   return model.dv.most_similar([inferred_vector], topn=len(model.dv))
#       4
#       5 def get_FSC_classes_row(ID):
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/doc2vec.py in infer_vector(self, doc_words, alpha, min_alpha, epochs, steps)
#     637                 train_document_dm(
#     638                     self, doc_words, doctag_indexes, alpha, work, neu1,
# --> 639                     learn_words=False, learn_hidden=False, doctag_vectors=doctag_vectors, doctags_lockf=doctags_lockf
#     640                 )
#     641             alpha -= alpha_delta
#
# KeyboardInterrupt:

# %%
train_classes_data
# Out:
#                             ID                                    classes
# 0     57065f86eb1ec950df04567a                    {'FSC': ['359', '372']}
# 1     5702662eeb1ec9c195055491                              {'FSC': '84'}
# 2     57026579eb1ec9b0a9bd00fe  {'FSC': ['72', '29', '51', '408', '409']}
# 3     570260bbeb1ec9244e6bdfe1                    {'FSC': ['210', '429']}
# 4     57026060eb1ec91ddf3047ef       {'FSC': ['144', '254', '173', '81']}
# ...                        ...                                        ...
# 7360  570261d1eb1ec93bc90e06ea                             {'FSC': '424'}
# 7361  57066c52eb1ec98afebf7a43                             {'FSC': '424'}
# 7362  57064db8eb1ec901ec1acac0                     {'FSC': ['53', '141']}
# 7363  570261d1eb1ec93bc90de880                    {'FSC': ['248', '285']}
# 7364  57066c52eb1ec98afebf58ad                              {'FSC': '62'}
#
# [7311 rows x 2 columns]
